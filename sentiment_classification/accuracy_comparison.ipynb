# %%
# dependencies
import pandas as pd
from textblob import TextBlob

# %%
# Import in data
df = pd.read_json('preprocessed_headlines.json')

# %%
df = df[['title', 'sentiment_human', 'compound_score']]

# %%
# Determine sentiment category for each NLTK compound score
df['NLTK'] = 0
df.loc[df['compound_score'] > 0.2, 'NLTK'] = 1
df.loc[df['compound_score'] < -0.2, 'NLTK'] = -1
df.head(5)
# Out:
#                                                title  sentiment_human  \
# 0  I could be deported because my parents came he...               -1
# 1  First Latino tapped to head DHS signals shift ...                0
# 2  Tony Pham, interim director of Immigration and...                0
# 3  More than two-thirds of undocumented immigrant...                0
# 4  Biden to meet with struggling workers, small-b...               -1
#
#    compound_score  NLTK
# 0          0.1027     0
# 1          0.0000     0
# 2          0.0000     0
# 3         -0.3818    -1
# 4         -0.7845    -1

# %%
# Label each NLTK sentiment as correct or incorrect
df['NLTK_acc'] = 0
df.loc[df['NLTK'] == df['sentiment_human'], 'NLTK_acc'] = 1
df.head(5)
# Out:
#                                                title  sentiment_human  \
# 0  I could be deported because my parents came he...               -1
# 1  First Latino tapped to head DHS signals shift ...                0
# 2  Tony Pham, interim director of Immigration and...                0
# 3  More than two-thirds of undocumented immigrant...                0
# 4  Biden to meet with struggling workers, small-b...               -1
#
#    compound_score  NLTK  NLTK_acc
# 0          0.1027     0         0
# 1          0.0000     0         1
# 2          0.0000     0         1
# 3         -0.3818    -1         0
# 4         -0.7845    -1         1

# %%
# Determine total number of correct classifications by NLTK
NLTK_correct = df.groupby('NLTK_acc').count()['title'][1]
NLTK_correct
# Out:
# 2092

# %%
# Determine NLTK accuracy
NLTK_accuracy = NLTK_correct/len(df)
NLTK_accuracy
# Out:
# 0.6763659877141933

# %%
# Calculate sentiment polarity using TextBlob
df['textblob_score'] = df['title'].apply(lambda x: TextBlob(x).sentiment.polarity)
df.head(5)
# Out:
#                                                title  sentiment_human  \
# 0  I could be deported because my parents came he...               -1
# 1  First Latino tapped to head DHS signals shift ...                0
# 2  Tony Pham, interim director of Immigration and...                0
# 3  More than two-thirds of undocumented immigrant...                0
# 4  Biden to meet with struggling workers, small-b...               -1
#
#    compound_score  NLTK  NLTK_acc  textblob_score
# 0          0.1027     0         0        0.200000
# 1          0.0000     0         1        0.250000
# 2          0.0000     0         1       -0.155556
# 3         -0.3818    -1         0        0.250000
# 4         -0.7845    -1         1        0.200000

# %%
# Determine sentiment category for each TextBlog compound score
df['TextBlob'] = 0
df.loc[df['textblob_score'] > 0.2, 'TextBlob'] = 1
df.loc[df['textblob_score'] < -0.2, 'TextBlob'] = -1
df.head(5)
# Out:
#                                                title  sentiment_human  \
# 0  I could be deported because my parents came he...               -1
# 1  First Latino tapped to head DHS signals shift ...                0
# 2  Tony Pham, interim director of Immigration and...                0
# 3  More than two-thirds of undocumented immigrant...                0
# 4  Biden to meet with struggling workers, small-b...               -1
#
#    compound_score  NLTK  NLTK_acc  textblob_score  TextBlob
# 0          0.1027     0         0        0.200000         0
# 1          0.0000     0         1        0.250000         1
# 2          0.0000     0         1       -0.155556         0
# 3         -0.3818    -1         0        0.250000         1
# 4         -0.7845    -1         1        0.200000         0

# %%
# Label each NLTK sentiment as correct or incorrect
df['TextBlob_acc'] = 0
df.loc[df['TextBlob'] == df['sentiment_human'], 'TextBlob'] = 1
df.head(5)
# Out:
#                                                title  sentiment_human  \
# 0  I could be deported because my parents came he...               -1
# 1  First Latino tapped to head DHS signals shift ...                0
# 2  Tony Pham, interim director of Immigration and...                0
# 3  More than two-thirds of undocumented immigrant...                0
# 4  Biden to meet with struggling workers, small-b...               -1
#
#    compound_score  NLTK  NLTK_acc  textblob_score  TextBlob  TextBlob_acc
# 0          0.1027     0         0        0.200000         0             0
# 1          0.0000     0         1        0.250000         1             0
# 2          0.0000     0         1       -0.155556         1             0
# 3         -0.3818    -1         0        0.250000         1             0
# 4         -0.7845    -1         1        0.200000         0             0

# %%
df.groupby('TextBlob').count()
# Out:
#           title  sentiment_human  compound_score  NLTK  NLTK_acc  \
# TextBlob
# -1           33               33              33    33        33
#  0         1629             1629            1629  1629      1629
#  1         1431             1431            1431  1431      1431
#
#           textblob_score  TextBlob_acc
# TextBlob
# -1                    33            33
#  0                  1629          1629
#  1                  1431          1431

# %%
# Determine total number of correct classifications by NLTK
TextBlob_correct = df.groupby('TextBlob_acc').count()['title']
TextBlob_correct
# Out:
# TextBlob_acc
# 0    3093
# Name: title, dtype: int64
