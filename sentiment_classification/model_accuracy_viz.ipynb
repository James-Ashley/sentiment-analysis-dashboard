# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
acc_data = [
    {'model': 'Naive Bayes', 'accuracy': 0.635, 'type': 'ours'},
    {'model': 'One vs. Rest', 'accuracy': 0.639, 'type': 'ours'},
    {'model': 'Multilayer Perceptron', 'accuracy': 0.628, 'type': 'ours'},
    {'model': 'TextBlob (trained)', 'accuracy': 0.56, 'type': 'prof'},
    {'model': 'NLTK Vader', 'accuracy': 0.67, 'type': 'prof'}];

df = pd.DataFrame(acc_data)
df
# Out:
#                    model  accuracy  type
# 0            Naive Bayes     0.635  ours
# 1           One vs. Rest     0.639  ours
# 2  Multilayer Perceptron     0.628  ours
# 3     TextBlob (trained)     0.560  prof
# 4             NLTK Vader     0.670  prof

# %%
# Set style for all graphs
plt.style.use('fivethirtyeight')

# %%
plt.bar(df['model'], df['accuracy'])
plt.title('Comparison of Model Accuracy')
plt.xticks(rotation=45)
plt.ylabel('Accuracy')
plt.tight_layout()
plt.savefig('modelaccuracy.png')
