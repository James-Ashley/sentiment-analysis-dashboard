# %% [markdown]
# ## References
# * https://medium.com/@nicharuch/collocations-identifying-phrases-that-act-like-individual-words-in-nlp-f58a93a2f84a
# * Sentiment Lexicons: https://sites.google.com/site/datascienceslab/projects/multilingualsentiment
# * https://stackoverflow.com/questions/49088978/how-to-create-corpus-from-pandas-data-frame-to-operate-with-nltk/49104725
# * https://stackoverflow.com/questions/26091769/finding-trigrams-for-entire-corpus-with-nltk

# %%
# Dependencies
import pymongo
import os, os.path
from dotenv import load_dotenv
import spacy
import re
import string
import nltk
from nltk.corpus import stopwords
import json
import pandas as pd
from nltk import FreqDist

# %%
# Load in database access info
load_dotenv()
username = os.getenv("db_username")
password = os.getenv("db_password")

# %%
# Connect to database
conn = f"mongodb+srv://{username}:{password}@clusterprime.mpaq0.mongodb.net/ETL?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.ETL

# %%
# Pull all data from collection
news_data = db.NFTA.find({})

# %% [markdown]
# ## Analyze Bigrams of Headlines

# %%
# Store headlines in list
headlines = []
for article in news_data:
    headlines.append(article['title'])

# %%
# Load spacy
nlp = spacy.load('en_core_web_sm')

# Function to clean and lemmatize comments
def clean_comments(text):
    #remove punctuations
    regex = re.compile('[' + re.escape(string.punctuation) + '\\r\\t\\n]')
    nopunct = regex.sub("", str(text))
    #use spacy to lemmatize comments
    doc = nlp(nopunct, disable=['parser','ner'])
    lemma = [token.lemma_ for token in doc]
    return lemma

# Apply function to clean and lemmatize comments
lemmatized = clean_comments(headlines)

# Make all words lowercase
lemmatized_headlines_1 = [word.lower() for word in lemmatized]

# %%
# Lemmatize word "aliens" - missed by spacy
headlines_clean = []
for word in lemmatized_headlines_1:
    if word == 'aliens':
        headlines_clean.append('alien')
    else:
        headlines_clean.append(word)

# %%
# Calculate bigrams
bigrams = nltk.collocations.BigramAssocMeasures()

bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(headlines_clean)

# %%
# Limit bigrams to at least 10 occurrences
bigramFinder.apply_freq_filter(10)

# Pull out bigrams and PMI scores
headline_bigrams = list(bigramFinder.score_ngrams(bigrams.pmi))

# %%
# Get english stopwords
en_stopwords = set(stopwords.words('english'))

# Function to remove function words from bigrams
def rightTypes(ngram):
    if '-pron-' in ngram or 't' in ngram:
        return False
    # Why is this not iterating through the tuple?
    for word in ngram:
        if word in en_stopwords or word.isspace():
            return False
        elif word in ('5', "'", '’s'):
            return False
    types_avoid = ('CC', 'DT', 'IN', 'POS', 'TO', 'SYM')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in types_avoid or tags[1][1] in types_avoid:
        return False
    else:
        return True

# Filter bigrams
filtered_headlines = [bigram for bigram in headline_bigrams if rightTypes(bigram[0])]

# %%
# Review filtered bigrams
filtered_headlines
# Out:
# [(('ilhan', 'omar'), 11.245711148410681),
#  (('hong', 'kong'), 11.152601744019199),
#  (('ruth', 'bader'), 10.982676742576889),
#  (('north', 'carolina'), 10.84274648143241),
#  (('town', 'hall'), 10.387066997656222),
#  (('fact', 'check'), 10.36600538212839),
#  (('pope', 'francis'), 10.294620748891628),
#  (('bader', 'ginsburg'), 10.134679836021936),
#  (('fox', 'news'), 10.108207624660746),
#  (('amy', 'coney'), 9.760284321240439),
#  (('coney', 'barrett'), 9.612185682251306),
#  (('washington', 'post'), 9.608281227795388),
#  (('wall', 'street'), 9.567639243298043),
#  (('terror', 'attack'), 8.720249659438187),
#  (('health', 'care'), 8.69590509310314),
#  (('undocumented', 'immigrant'), 8.644807103820504),
#  (('kamala', 'harris'), 8.545271430269587),
#  (('illegal', 'alien'), 8.38504783001957),
#  (('supreme', 'court'), 8.167452134490183),
#  (('new', 'york'), 8.054569661058673),
#  (('vp', 'debate'), 8.013050391620405),
#  (('border', 'patrol'), 7.9826767425768885),
#  (('white', 'house'), 7.9153917832641785),
#  (('presidential', 'debate'), 7.783568545497637),
#  (('asian', 'american'), 7.754570670046045),
#  (('battleground', 'state'), 7.754570670046045),
#  (('asian', 'americans'), 7.147913098225569),
#  (('refugee', 'camp'), 7.11532935377293),
#  (('migrant', 'caravan'), 7.096333524372454),
#  (('border', 'wall'), 7.070139583827228),
#  (('latino', 'voter'), 6.671719765510527),
#  (('immigration', 'policy'), 6.567639243298045),
#  (('joe', 'biden'), 6.416138311505533),
#  (('american', 'voter'), 6.022317203229161),
#  (('migrant', 'camp'), 5.886880158743505),
#  (('illegal', 'immigrant'), 5.885815203324297),
#  (('presidential', 'election'), 5.749783461804983),
#  (('donald', 'trump'), 5.742395034582472),
#  (('2020', 'election'), 5.677374966276934),
#  (('melania', 'trump'), 5.624769350583957),
#  (('trump', 'administration'), 5.591602486648757),
#  (('texas', 'border'), 5.4466238423366775),
#  (('migrant', 'child'), 5.213690475010614),
#  (('illegal', 'immigration'), 5.101664778793975),
#  (('us', 'election'), 4.679323238066456),
#  (('illegal', 'migrant'), 4.52142468831522),
#  (('biden', 'win'), 4.072183910288173),
#  (('president', 'trump'), 3.9488459120498973),
#  (('say', 'trump'), 2.09004960464242),
#  (('trump', 'say'), 1.8270151988086276),
#  (('trump', 'biden'), 1.2321248231578608)]

# %%
# Read in pos/negative word lists

pos_words = []
with open('positive_words_en.txt') as p:
    for row in p:
        word = p.readline()
        pos_words.append(word.rstrip())

neg_words = [] 
with open('negative_words_en.txt') as n:
    for row in n:
        word = n.readline()
        neg_words.append(word.rstrip())

# %%
# Create list of words w/ sentiment from bigrams
words_sentiment = []
word_check = []
for bigram in filtered_headlines:
    word_dict = {}
    sentiment = 'not labelled'
    first_word = bigram[0][0]
    second_word = bigram[0][1]

    if first_word not in word_check:
        word_check.append(first_word)
        if first_word in pos_words:
            sentiment = 1
        if first_word in neg_words:
            sentiment = -1
        word_dict = {'id': first_word, 'group': sentiment}
        words_sentiment.append(word_dict)
        
        
    if second_word not in word_check:
        word_check.append(second_word)
        if second_word in pos_words:
            sentiment = 1
        if second_word in neg_words:
            sentiment = -1
        word_dict = {'id': second_word, 'group': sentiment}
        words_sentiment.append(word_dict)

# %%
# Check sentiment labels for accuracy
for word in words_sentiment:
    print(word)
# Out:
# {'id': 'ilhan', 'group': 'not labelled'}
# {'id': 'omar', 'group': 'not labelled'}
# {'id': 'hong', 'group': 'not labelled'}
# {'id': 'kong', 'group': 'not labelled'}
# {'id': 'ruth', 'group': 'not labelled'}
# {'id': 'bader', 'group': 'not labelled'}
# {'id': 'north', 'group': 'not labelled'}
# {'id': 'carolina', 'group': 'not labelled'}
# {'id': 'town', 'group': 'not labelled'}
# {'id': 'hall', 'group': 'not labelled'}
# {'id': 'fact', 'group': 'not labelled'}
# {'id': 'check', 'group': 'not labelled'}
# {'id': 'pope', 'group': 'not labelled'}
# {'id': 'francis', 'group': 'not labelled'}
# {'id': 'ginsburg', 'group': 'not labelled'}
# {'id': 'fox', 'group': 'not labelled'}
# {'id': 'news', 'group': 'not labelled'}
# {'id': 'amy', 'group': 'not labelled'}
# {'id': 'coney', 'group': 'not labelled'}
# {'id': 'barrett', 'group': 'not labelled'}
# {'id': 'washington', 'group': 'not labelled'}
# {'id': 'post', 'group': 'not labelled'}
# {'id': 'wall', 'group': 'not labelled'}
# {'id': 'street', 'group': 'not labelled'}
# {'id': 'terror', 'group': 'not labelled'}
# {'id': 'attack', 'group': 'not labelled'}
# {'id': 'health', 'group': 'not labelled'}
# {'id': 'care', 'group': 'not labelled'}
# {'id': 'undocumented', 'group': -1}
# {'id': 'immigrant', 'group': -1}
# {'id': 'kamala', 'group': 'not labelled'}
# {'id': 'harris', 'group': 'not labelled'}
# {'id': 'illegal', 'group': 'not labelled'}
# {'id': 'alien', 'group': 'not labelled'}
# {'id': 'supreme', 'group': 'not labelled'}
# {'id': 'court', 'group': 'not labelled'}
# {'id': 'new', 'group': 'not labelled'}
# {'id': 'york', 'group': 'not labelled'}
# {'id': 'vp', 'group': 'not labelled'}
# {'id': 'debate', 'group': 'not labelled'}
# {'id': 'border', 'group': 'not labelled'}
# {'id': 'patrol', 'group': 'not labelled'}
# {'id': 'white', 'group': 'not labelled'}
# {'id': 'house', 'group': 'not labelled'}
# {'id': 'presidential', 'group': 'not labelled'}
# {'id': 'asian', 'group': 'not labelled'}
# {'id': 'american', 'group': 'not labelled'}
# {'id': 'battleground', 'group': 'not labelled'}
# {'id': 'state', 'group': 'not labelled'}
# {'id': 'americans', 'group': 'not labelled'}
# {'id': 'refugee', 'group': 'not labelled'}
# {'id': 'camp', 'group': 'not labelled'}
# {'id': 'migrant', 'group': 'not labelled'}
# {'id': 'caravan', 'group': 'not labelled'}
# {'id': 'latino', 'group': 'not labelled'}
# {'id': 'voter', 'group': 'not labelled'}
# {'id': 'immigration', 'group': 'not labelled'}
# {'id': 'policy', 'group': 'not labelled'}
# {'id': 'joe', 'group': 'not labelled'}
# {'id': 'biden', 'group': 'not labelled'}
# {'id': 'election', 'group': 'not labelled'}
# {'id': 'donald', 'group': 'not labelled'}
# {'id': 'trump', 'group': 'not labelled'}
# {'id': '2020', 'group': 'not labelled'}
# {'id': 'melania', 'group': 'not labelled'}
# {'id': 'administration', 'group': 'not labelled'}
# {'id': 'texas', 'group': 'not labelled'}
# {'id': 'child', 'group': 'not labelled'}
# {'id': 'us', 'group': 'not labelled'}
# {'id': 'win', 'group': 1}
# {'id': 'president', 'group': 'not labelled'}
# {'id': 'say', 'group': 'not labelled'}

# %%
# Revise sentiment labels
for word in words_sentiment:
    if word['group'] == 'not labelled':
        if word['id'] in ['terror', 'attack', 'battleground', 'illegal']:
            word['group'] = -1
        else:
            word['group'] = 0

# %%
# Check sentiment labels after editing
for word in words_sentiment:
    print(word)
# Out:
# {'id': 'ilhan', 'group': 0}
# {'id': 'omar', 'group': 0}
# {'id': 'hong', 'group': 0}
# {'id': 'kong', 'group': 0}
# {'id': 'ruth', 'group': 0}
# {'id': 'bader', 'group': 0}
# {'id': 'north', 'group': 0}
# {'id': 'carolina', 'group': 0}
# {'id': 'town', 'group': 0}
# {'id': 'hall', 'group': 0}
# {'id': 'fact', 'group': 0}
# {'id': 'check', 'group': 0}
# {'id': 'pope', 'group': 0}
# {'id': 'francis', 'group': 0}
# {'id': 'ginsburg', 'group': 0}
# {'id': 'fox', 'group': 0}
# {'id': 'news', 'group': 0}
# {'id': 'amy', 'group': 0}
# {'id': 'coney', 'group': 0}
# {'id': 'barrett', 'group': 0}
# {'id': 'washington', 'group': 0}
# {'id': 'post', 'group': 0}
# {'id': 'wall', 'group': 0}
# {'id': 'street', 'group': 0}
# {'id': 'terror', 'group': -1}
# {'id': 'attack', 'group': -1}
# {'id': 'health', 'group': 0}
# {'id': 'care', 'group': 0}
# {'id': 'undocumented', 'group': -1}
# {'id': 'immigrant', 'group': -1}
# {'id': 'kamala', 'group': 0}
# {'id': 'harris', 'group': 0}
# {'id': 'illegal', 'group': -1}
# {'id': 'alien', 'group': 0}
# {'id': 'supreme', 'group': 0}
# {'id': 'court', 'group': 0}
# {'id': 'new', 'group': 0}
# {'id': 'york', 'group': 0}
# {'id': 'vp', 'group': 0}
# {'id': 'debate', 'group': 0}
# {'id': 'border', 'group': 0}
# {'id': 'patrol', 'group': 0}
# {'id': 'white', 'group': 0}
# {'id': 'house', 'group': 0}
# {'id': 'presidential', 'group': 0}
# {'id': 'asian', 'group': 0}
# {'id': 'american', 'group': 0}
# {'id': 'battleground', 'group': -1}
# {'id': 'state', 'group': 0}
# {'id': 'americans', 'group': 0}
# {'id': 'refugee', 'group': 0}
# {'id': 'camp', 'group': 0}
# {'id': 'migrant', 'group': 0}
# {'id': 'caravan', 'group': 0}
# {'id': 'latino', 'group': 0}
# {'id': 'voter', 'group': 0}
# {'id': 'immigration', 'group': 0}
# {'id': 'policy', 'group': 0}
# {'id': 'joe', 'group': 0}
# {'id': 'biden', 'group': 0}
# {'id': 'election', 'group': 0}
# {'id': 'donald', 'group': 0}
# {'id': 'trump', 'group': 0}
# {'id': '2020', 'group': 0}
# {'id': 'melania', 'group': 0}
# {'id': 'administration', 'group': 0}
# {'id': 'texas', 'group': 0}
# {'id': 'child', 'group': 0}
# {'id': 'us', 'group': 0}
# {'id': 'win', 'group': 1}
# {'id': 'president', 'group': 0}
# {'id': 'say', 'group': 0}

# %%
# Format bigrams
links = []
for bigram in filtered_headlines:
    word_dict = {
        'source': bigram[0][0],
        'target': bigram[0][1],
        'value': round(bigram[1])
    }
    links.append(word_dict)

# %%
# Format data for arc diagram
headline_bigrams_formatted = {'nodes': words_sentiment, 'links': links}
headline_bigrams_formatted
# Out:
# {'nodes': [{'id': 'ilhan', 'group': 0},
#   {'id': 'omar', 'group': 0},
#   {'id': 'hong', 'group': 0},
#   {'id': 'kong', 'group': 0},
#   {'id': 'ruth', 'group': 0},
#   {'id': 'bader', 'group': 0},
#   {'id': 'north', 'group': 0},
#   {'id': 'carolina', 'group': 0},
#   {'id': 'town', 'group': 0},
#   {'id': 'hall', 'group': 0},
#   {'id': 'fact', 'group': 0},
#   {'id': 'check', 'group': 0},
#   {'id': 'pope', 'group': 0},
#   {'id': 'francis', 'group': 0},
#   {'id': 'ginsburg', 'group': 0},
#   {'id': 'fox', 'group': 0},
#   {'id': 'news', 'group': 0},
#   {'id': 'amy', 'group': 0},
#   {'id': 'coney', 'group': 0},
#   {'id': 'barrett', 'group': 0},
#   {'id': 'washington', 'group': 0},
#   {'id': 'post', 'group': 0},
#   {'id': 'wall', 'group': 0},
#   {'id': 'street', 'group': 0},
#   {'id': 'terror', 'group': -1},
#   {'id': 'attack', 'group': -1},
#   {'id': 'health', 'group': 0},
#   {'id': 'care', 'group': 0},
#   {'id': 'undocumented', 'group': -1},
#   {'id': 'immigrant', 'group': -1},
#   {'id': 'kamala', 'group': 0},
#   {'id': 'harris', 'group': 0},
#   {'id': 'illegal', 'group': -1},
#   {'id': 'alien', 'group': 0},
#   {'id': 'supreme', 'group': 0},
#   {'id': 'court', 'group': 0},
#   {'id': 'new', 'group': 0},
#   {'id': 'york', 'group': 0},
#   {'id': 'vp', 'group': 0},
#   {'id': 'debate', 'group': 0},
#   {'id': 'border', 'group': 0},
#   {'id': 'patrol', 'group': 0},
#   {'id': 'white', 'group': 0},
#   {'id': 'house', 'group': 0},
#   {'id': 'presidential', 'group': 0},
#   {'id': 'asian', 'group': 0},
#   {'id': 'american', 'group': 0},
#   {'id': 'battleground', 'group': -1},
#   {'id': 'state', 'group': 0},
#   {'id': 'americans', 'group': 0},
#   {'id': 'refugee', 'group': 0},
#   {'id': 'camp', 'group': 0},
#   {'id': 'migrant', 'group': 0},
#   {'id': 'caravan', 'group': 0},
#   {'id': 'latino', 'group': 0},
#   {'id': 'voter', 'group': 0},
#   {'id': 'immigration', 'group': 0},
#   {'id': 'policy', 'group': 0},
#   {'id': 'joe', 'group': 0},
#   {'id': 'biden', 'group': 0},
#   {'id': 'election', 'group': 0},
#   {'id': 'donald', 'group': 0},
#   {'id': 'trump', 'group': 0},
#   {'id': '2020', 'group': 0},
#   {'id': 'melania', 'group': 0},
#   {'id': 'administration', 'group': 0},
#   {'id': 'texas', 'group': 0},
#   {'id': 'child', 'group': 0},
#   {'id': 'us', 'group': 0},
#   {'id': 'win', 'group': 1},
#   {'id': 'president', 'group': 0},
#   {'id': 'say', 'group': 0}],
#  'links': [{'source': 'ilhan', 'target': 'omar', 'value': 11},
#   {'source': 'hong', 'target': 'kong', 'value': 11},
#   {'source': 'ruth', 'target': 'bader', 'value': 11},
#   {'source': 'north', 'target': 'carolina', 'value': 11},
#   {'source': 'town', 'target': 'hall', 'value': 10},
#   {'source': 'fact', 'target': 'check', 'value': 10},
#   {'source': 'pope', 'target': 'francis', 'value': 10},
#   {'source': 'bader', 'target': 'ginsburg', 'value': 10},
#   {'source': 'fox', 'target': 'news', 'value': 10},
#   {'source': 'amy', 'target': 'coney', 'value': 10},
#   {'source': 'coney', 'target': 'barrett', 'value': 10},
#   {'source': 'washington', 'target': 'post', 'value': 10},
#   {'source': 'wall', 'target': 'street', 'value': 10},
#   {'source': 'terror', 'target': 'attack', 'value': 9},
#   {'source': 'health', 'target': 'care', 'value': 9},
#   {'source': 'undocumented', 'target': 'immigrant', 'value': 9},
#   {'source': 'kamala', 'target': 'harris', 'value': 9},
#   {'source': 'illegal', 'target': 'alien', 'value': 8},
#   {'source': 'supreme', 'target': 'court', 'value': 8},
#   {'source': 'new', 'target': 'york', 'value': 8},
#   {'source': 'vp', 'target': 'debate', 'value': 8},
#   {'source': 'border', 'target': 'patrol', 'value': 8},
#   {'source': 'white', 'target': 'house', 'value': 8},
#   {'source': 'presidential', 'target': 'debate', 'value': 8},
#   {'source': 'asian', 'target': 'american', 'value': 8},
#   {'source': 'battleground', 'target': 'state', 'value': 8},
#   {'source': 'asian', 'target': 'americans', 'value': 7},
#   {'source': 'refugee', 'target': 'camp', 'value': 7},
#   {'source': 'migrant', 'target': 'caravan', 'value': 7},
#   {'source': 'border', 'target': 'wall', 'value': 7},
#   {'source': 'latino', 'target': 'voter', 'value': 7},
#   {'source': 'immigration', 'target': 'policy', 'value': 7},
#   {'source': 'joe', 'target': 'biden', 'value': 6},
#   {'source': 'american', 'target': 'voter', 'value': 6},
#   {'source': 'migrant', 'target': 'camp', 'value': 6},
#   {'source': 'illegal', 'target': 'immigrant', 'value': 6},
#   {'source': 'presidential', 'target': 'election', 'value': 6},
#   {'source': 'donald', 'target': 'trump', 'value': 6},
#   {'source': '2020', 'target': 'election', 'value': 6},
#   {'source': 'melania', 'target': 'trump', 'value': 6},
#   {'source': 'trump', 'target': 'administration', 'value': 6},
#   {'source': 'texas', 'target': 'border', 'value': 5},
#   {'source': 'migrant', 'target': 'child', 'value': 5},
#   {'source': 'illegal', 'target': 'immigration', 'value': 5},
#   {'source': 'us', 'target': 'election', 'value': 5},
#   {'source': 'illegal', 'target': 'migrant', 'value': 5},
#   {'source': 'biden', 'target': 'win', 'value': 4},
#   {'source': 'president', 'target': 'trump', 'value': 4},
#   {'source': 'say', 'target': 'trump', 'value': 2},
#   {'source': 'trump', 'target': 'say', 'value': 2},
#   {'source': 'trump', 'target': 'biden', 'value': 1}]}

# %%
# Remove words that only occur in one bigram
words_keep = []
for word in word_check:
    word_count = 0
    for bi_dict in links:
        if word == bi_dict['source'] or word == bi_dict['target']:
            word_count += 1
    if word_count > 1:
        words_keep.append(word)
        
links_filtered = []
words_sentiment_filtered = []
for word in words_keep:
    for bi_dict in links:
        if word == bi_dict['source'] or word == bi_dict['target']:
            links_filtered.append(bi_dict)

words_filtered = []
for bigram in links_filtered:
    if bigram['source'] not in words_filtered:
        words_filtered.append(bigram['source'])
    if bigram['target'] not in words_filtered:
        words_filtered.append(bigram['target'])

words_sentiment_filtered = []
for word in words_filtered:
    for sent_dict in words_sentiment:
        if word == sent_dict['id']:
            words_sentiment_filtered.append(sent_dict)

# %%
# Format data for arc diagram
headline_bigrams_filtered = {'nodes': words_sentiment_filtered, 'links': links_filtered}
headline_bigrams_filtered
# Out:
# {'nodes': [{'id': 'ruth', 'group': 0},
#   {'id': 'bader', 'group': 0},
#   {'id': 'ginsburg', 'group': 0},
#   {'id': 'amy', 'group': 0},
#   {'id': 'coney', 'group': 0},
#   {'id': 'barrett', 'group': 0},
#   {'id': 'wall', 'group': 0},
#   {'id': 'street', 'group': 0},
#   {'id': 'border', 'group': 0},
#   {'id': 'undocumented', 'group': -1},
#   {'id': 'immigrant', 'group': -1},
#   {'id': 'illegal', 'group': -1},
#   {'id': 'alien', 'group': 0},
#   {'id': 'immigration', 'group': 0},
#   {'id': 'migrant', 'group': 0},
#   {'id': 'vp', 'group': 0},
#   {'id': 'debate', 'group': 0},
#   {'id': 'presidential', 'group': 0},
#   {'id': 'patrol', 'group': 0},
#   {'id': 'texas', 'group': 0},
#   {'id': 'election', 'group': 0},
#   {'id': 'asian', 'group': 0},
#   {'id': 'american', 'group': 0},
#   {'id': 'americans', 'group': 0},
#   {'id': 'voter', 'group': 0},
#   {'id': 'refugee', 'group': 0},
#   {'id': 'camp', 'group': 0},
#   {'id': 'caravan', 'group': 0},
#   {'id': 'child', 'group': 0},
#   {'id': 'latino', 'group': 0},
#   {'id': 'policy', 'group': 0},
#   {'id': 'joe', 'group': 0},
#   {'id': 'biden', 'group': 0},
#   {'id': 'win', 'group': 1},
#   {'id': 'trump', 'group': 0},
#   {'id': '2020', 'group': 0},
#   {'id': 'us', 'group': 0},
#   {'id': 'donald', 'group': 0},
#   {'id': 'melania', 'group': 0},
#   {'id': 'administration', 'group': 0},
#   {'id': 'president', 'group': 0},
#   {'id': 'say', 'group': 0}],
#  'links': [{'source': 'ruth', 'target': 'bader', 'value': 11},
#   {'source': 'bader', 'target': 'ginsburg', 'value': 10},
#   {'source': 'amy', 'target': 'coney', 'value': 10},
#   {'source': 'coney', 'target': 'barrett', 'value': 10},
#   {'source': 'wall', 'target': 'street', 'value': 10},
#   {'source': 'border', 'target': 'wall', 'value': 7},
#   {'source': 'undocumented', 'target': 'immigrant', 'value': 9},
#   {'source': 'illegal', 'target': 'immigrant', 'value': 6},
#   {'source': 'illegal', 'target': 'alien', 'value': 8},
#   {'source': 'illegal', 'target': 'immigrant', 'value': 6},
#   {'source': 'illegal', 'target': 'immigration', 'value': 5},
#   {'source': 'illegal', 'target': 'migrant', 'value': 5},
#   {'source': 'vp', 'target': 'debate', 'value': 8},
#   {'source': 'presidential', 'target': 'debate', 'value': 8},
#   {'source': 'border', 'target': 'patrol', 'value': 8},
#   {'source': 'border', 'target': 'wall', 'value': 7},
#   {'source': 'texas', 'target': 'border', 'value': 5},
#   {'source': 'presidential', 'target': 'debate', 'value': 8},
#   {'source': 'presidential', 'target': 'election', 'value': 6},
#   {'source': 'asian', 'target': 'american', 'value': 8},
#   {'source': 'asian', 'target': 'americans', 'value': 7},
#   {'source': 'asian', 'target': 'american', 'value': 8},
#   {'source': 'american', 'target': 'voter', 'value': 6},
#   {'source': 'refugee', 'target': 'camp', 'value': 7},
#   {'source': 'migrant', 'target': 'camp', 'value': 6},
#   {'source': 'migrant', 'target': 'caravan', 'value': 7},
#   {'source': 'migrant', 'target': 'camp', 'value': 6},
#   {'source': 'migrant', 'target': 'child', 'value': 5},
#   {'source': 'illegal', 'target': 'migrant', 'value': 5},
#   {'source': 'latino', 'target': 'voter', 'value': 7},
#   {'source': 'american', 'target': 'voter', 'value': 6},
#   {'source': 'immigration', 'target': 'policy', 'value': 7},
#   {'source': 'illegal', 'target': 'immigration', 'value': 5},
#   {'source': 'joe', 'target': 'biden', 'value': 6},
#   {'source': 'biden', 'target': 'win', 'value': 4},
#   {'source': 'trump', 'target': 'biden', 'value': 1},
#   {'source': 'presidential', 'target': 'election', 'value': 6},
#   {'source': '2020', 'target': 'election', 'value': 6},
#   {'source': 'us', 'target': 'election', 'value': 5},
#   {'source': 'donald', 'target': 'trump', 'value': 6},
#   {'source': 'melania', 'target': 'trump', 'value': 6},
#   {'source': 'trump', 'target': 'administration', 'value': 6},
#   {'source': 'president', 'target': 'trump', 'value': 4},
#   {'source': 'say', 'target': 'trump', 'value': 2},
#   {'source': 'trump', 'target': 'say', 'value': 2},
#   {'source': 'trump', 'target': 'biden', 'value': 1},
#   {'source': 'say', 'target': 'trump', 'value': 2},
#   {'source': 'trump', 'target': 'say', 'value': 2}]}

# %%
# Save as JSON file
with open('headline_bigrams.json', 'w') as outfile:
    json.dump(headline_bigrams_filtered, outfile)

# %% [markdown]
# ## Analyze Bigrams of Full Text

# %%
# Store data in dataframe
df = pd.DataFrame(news_data)
df.head()
# Out:
#                         _id      keyword    source  \
# 0  5ff0c0da250c080ba07a092c  immigration  NBC News
# 1  5ff0c0da250c080ba07a092d  immigration  NBC News
# 2  5ff0c0da250c080ba07a092e  immigration  NBC News
# 3  5ff0c0da250c080ba07a092f  immigration  NBC News
# 4  5ff0c0da250c080ba07a0930  immigration  NBC News
#
#                             author  \
# 0                        Dip Patel
# 1                   Suzanne Gamboa
# 2                    Cynthia Silva
# 3  Julia Ainsley and Didi Martinez
# 4     Rebecca Shabad, Adam Edelman
#
#                                                title  \
# 0  I could be deported because my parents came he...
# 1  First Latino tapped to head DHS signals shift ...
# 2  Tony Pham, interim director of Immigration and...
# 3  More than two-thirds of undocumented immigrant...
# 4  Biden to meet with struggling workers, small-b...
#
#                                                  url             published  \
# 0  https://www.nbcnews.com/think/opinion/biden-s-...  2020-12-04T09:32:20Z
# 1  https://www.nbcnews.com/news/latino/first-lati...  2020-11-23T22:41:00Z
# 2  https://www.nbcnews.com/news/asian-america/ton...  2020-12-14T22:28:21Z
# 3  https://www.nbcnews.com/politics/immigration/s...  2020-12-16T22:46:58Z
# 4  https://www.nbcnews.com/politics/politics-news...  2020-12-02T21:56:00Z
#
#    compound_score  negative_score  positive_score  neutral_score  \
# 0          0.1027           0.000           0.104          0.896
# 1          0.0000           0.000           0.000          1.000
# 2          0.0000           0.000           0.000          1.000
# 3         -0.3818           0.157           0.000          0.843
# 4         -0.7845           0.365           0.000          0.635
#
#                                         text_excerpt  \
# 0  As an inpatient hospital pharmacist, I am part...
# 1  Alejandro Mayorkas, the first Latino chosen fo...
# 2  Tony Pham will be stepping down as the acting ...
# 3  WASHINGTON More than two-thirds of undocumente...
# 4  President-elect Joe Biden on Wednesday used a ...
#
#                                        text_complete sentiment_category
# 0  As an inpatient hospital pharmacist, I am part...            neutral
# 1  Alejandro Mayorkas, the first Latino chosen fo...            neutral
# 2  Tony Pham will be stepping down as the acting ...            neutral
# 3  WASHINGTON — More than two-thirds of undocumen...           negative
# 4  President-elect Joe Biden on Wednesday used a ...           negative

# %%
# Add ID column
df['id'] = df['source'] + " " + df['published']

# %%
# Check how many unique ID's there are
df['id'].nunique()
# Out:
# 3090

# %%
# Write full text of articles to txt files
for index, row in df.iterrows():
    _id = row['id']
    corp_id = _id.replace(" ", "").replace(':', '-')
    title = row['title']
    body = row['text_complete']
    file_name = 'full_news_text/' + str(corp_id) + '.txt'
    with open(file_name, 'a+', encoding='utf-8') as f:
        f.write(str(body) + ' ' + str(title))

# %%
# Create corpus
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
news_corpus = CategorizedPlaintextCorpusReader('full_news_text/', r'.*', cat_pattern=r'(.*) .*')

# %%
news_corpus.words()
# Out:
# ['Over', '12', ',', '000', 'men', ',', 'women', 'and', ...]

# %%
news_corpus.sents()
# Out:
# [['Over', '12', ',', '000', 'men', ',', 'women', 'and', 'children', 'ran', 'out', 'of', 'tents', 'in', 'panic', 'as', 'the', 'fire', 'destroyed', 'most', 'the', 'camp', '.'], ['European', 'officials', 'said', 'the', 'fate', 'of', '12', ',', '600', 'refugees', 'and', 'migrants', 'now', 'homeless', 'after', 'a', 'fire', 'at', 'their', 'camp', 'on', 'a', 'Greek', 'island', 'needs', 'to', 'be', 'addressed', 'as', 'a', 'top', 'priority', '.'], ...]

# %% [markdown]
# To remove wonky characters: https://www.browserling.com/tools/utf8-encode

# %%
fdist = nltk.FreqDist()  # Empty distribution

for filename in news_corpus.fileids():
    try:
        fdist.update(nltk.bigrams(news_corpus.words(filename)))
    except:
        print(filename)

# %%
fdist.N()
# Out:
# 26647756

# %%
from nltk.corpus import stopwords

# %%
en_stopwords = set(stopwords.words('english'))
text_list = []
for k,v in fdist.items():
    if v > 500:
        first = k[0].lower()
        second = k[1].lower()
        if first not in en_stopwords and second not in en_stopwords:
            if first not in string.punctuation and second not in string.punctuation:
                text_list.append(((first, second), v))

# %%
# Function to remove function words from bigrams
def rightTypes(ngram):
    for word in ngram:
        if word in en_stopwords or word.isspace():
            return False
        if word in ('5', "'", '’s', "\\'", '.-'):
            return False
        if len(word) <3:
            return False
        for char in word:
            if char in string.punctuation:
                return False
        if 'x' == word[0]:
            return False
        types_avoid = ('CC', 'DT', 'IN', 'POS', 'TO', 'SYM')
        tags = nltk.pos_tag(ngram)
    if tags[0][1] in types_avoid or tags[1][1] in types_avoid:
            return False
    else:
        return True

# Filter bigrams
filtered_text = [bigram for bigram in text_list if rightTypes(bigram[0])]

# %%
len(filtered_text)
# Out:
# 323

# %%
text_list
# Out:
# [(('officials', 'said'), 1044),
#  (('also', 'said'), 1056),
#  (('refugee', 'camp'), 580),
#  (('prime', 'minister'), 1784),
#  (('public', 'health'), 2288),
#  (('national', 'security'), 1914),
#  (('last', 'week'), 3202),
#  (('news', 'agency'), 647),
#  ((',”', 'said'), 2134),
#  (('human', 'rights'), 2279),
#  (('european', 'union'), 1056),
#  (('country', '’'), 608),
#  (('asylum', 'seekers'), 1673),
#  ((',\\', 'xe2'), 28374),
#  (('x9d', 'said'), 3318),
#  ((".'", 'b'), 7004),
#  (('civil', 'rights'), 1268),
#  (('getty', 'images'), 1050),
#  (('social', 'media'), 2863),
#  (('wall', 'street'), 1347),
#  (('street', 'journal'), 539),
#  (('last', 'week'), 561),
#  (('last', 'month'), 1850),
#  (('first', 'time'), 2160),
#  (('.\\', 'xe2'), 24177),
#  (('000', 'people'), 1721),
#  (('tuesday', 'night'), 642),
#  (('associated', 'press'), 1332),
#  (('al', 'jazeera'), 2543),
#  (('police', 'officers'), 853),
#  (('two', 'years'), 1573),
#  (('last', 'year'), 2719),
#  (('donald', 'trump'), 11745),
#  (('joe', 'biden'), 13471),
#  (('trump', '’'), 3854),
#  (('us', 'president'), 678),
#  (('president', 'donald'), 6731),
#  (('white', 'house'), 9617),
#  (('vice', 'president'), 3885),
#  (('president', 'joe'), 1224),
#  (('presidential', 'election'), 2659),
#  (('november', '3'), 720),
#  (('united', 'states'), 11877),
#  (('coronavirus', 'pandemic'), 3447),
#  (('foreign', 'workers'), 1342),
#  (('green', 'cards'), 1295),
#  (('mexico', 'border'), 1059),
#  (('trump', 'administration'), 6659),
#  (('supreme', 'court'), 10508),
#  (('high', 'court'), 744),
#  (('president', 'barack'), 1758),
#  (('barack', 'obama'), 3212),
#  (('would', 'make'), 742),
#  (('border', 'wall'), 1132),
#  (('central', 'america'), 802),
#  (('border', 'patrol'), 1937),
#  (('rio', 'grande'), 708),
#  (('biden', 'said'), 2265),
#  (('biden', '’'), 1956),
#  (('border', 'protection'), 779),
#  (('ap', 'photo'), 654),
#  (('executive', 'order'), 852),
#  (('biden', 'would'), 982),
#  (('north', 'korea'), 622),
#  (('undocumented', 'immigrants'), 1679),
#  (('new', 'york'), 8908),
#  (('10', 'years'), 636),
#  (('5', 'million'), 1069),
#  (('million', 'people'), 1395),
#  (('illegal', 'aliens'), 2593),
#  (('voting', 'rights'), 708),
#  (('president', 'trump'), 7332),
#  (('attorney', 'general'), 1145),
#  (('immigration', 'policies'), 1207),
#  (('x9d', 'trump'), 1125),
#  (('."', 'b'), 937),
#  (('young', 'people'), 723),
#  (('prime', 'minister'), 631),
#  (('19', 'pandemic'), 1525),
#  (('high', 'school'), 827),
#  (('told', 'al'), 1098),
#  (('tested', 'positive'), 2004),
#  (('two', 'days'), 618),
#  (('x99t', 'know'), 606),
#  (('x99t', 'want'), 585),
#  (('?\\', 'xe2'), 1392),
#  (('south', 'asian'), 867),
#  (('asian', 'americans'), 1578),
#  (('justice', 'department'), 1615),
#  (('pew', 'research'), 612),
#  (('research', 'center'), 574),
#  (('world', 'war'), 678),
#  (('views', 'expressed'), 540),
#  (('homeland', 'security'), 3056),
#  (('nation', '’'), 640),
#  (('immigration', 'system'), 893),
#  (('immigration', 'policy'), 692),
#  (('middle', 'east'), 1077),
#  (('first', 'black'), 648),
#  (('asian', 'american'), 2028),
#  (('vice', 'president'), 3912),
#  (('vice', 'presidential'), 1140),
#  (('presidential', 'nominee'), 1505),
#  (('four', 'years'), 3846),
#  (('years', 'later'), 797),
#  (('kamala', 'harris'), 3797),
#  (('trump', 'said'), 2712),
#  (('north', 'carolina'), 3123),
#  (('black', 'woman'), 597),
#  (('president', '’'), 578),
#  (('trump', 'campaign'), 2770),
#  (('black', 'voters'), 854),
#  (('running', 'mate'), 1024),
#  (('law', 'enforcement'), 2634),
#  (('bernie', 'sanders'), 951),
#  (('alexandria', 'ocasio'), 625),
#  (('court', 'justice'), 690),
#  (('presidential', 'candidate'), 1307),
#  (('feel', 'like'), 798),
#  (('x99s', 'campaign'), 540),
#  (('!\\', 'xe2'), 579),
#  (('x99s', 'going'), 546),
#  (('told', 'reporters'), 954),
#  (('human', 'rights'), 1005),
#  (('state', '’'), 712),
#  (('saudi', 'arabia'), 611),
#  (('coronavirus', 'outbreak'), 3024),
#  (('6', 'million'), 654),
#  (('2', 'million'), 921),
#  (('united', 'nations'), 1322),
#  (('novel', 'coronavirus'), 3030),
#  (('disease', 'control'), 694),
#  (('new', 'coronavirus'), 558),
#  (('19', 'cases'), 785),
#  (('coronavirus', 'cases'), 1079),
#  (('new', 'cases'), 760),
#  (('two', 'weeks'), 1368),
#  (('social', 'distancing'), 894),
#  (('7', 'million'), 516),
#  (('every', 'day'), 961),
#  (('years', 'ago'), 3420),
#  (('every', 'single'), 543),
#  (('recent', 'years'), 1062),
#  (('three', 'years'), 1080),
#  (('would', 'allow'), 523),
#  (('climate', 'change'), 2195),
#  (('mental', 'health'), 977),
#  (('san', 'francisco'), 1755),
#  (('puerto', 'rico'), 1069),
#  (('look', 'like'), 721),
#  (('x9ci', 'think'), 573),
#  (('8', 'million'), 522),
#  (('.”', '“'), 1436),
#  (('go', 'back'), 735),
#  (('two', 'months'), 575),
#  (('years', 'old'), 768),
#  (('press', 'conference'), 582),
#  (('even', 'though'), 1399),
#  (('election', 'results'), 802),
#  (('took', 'place'), 624),
#  (('long', 'time'), 612),
#  (('american', 'voters'), 660),
#  (('systemic', 'racism'), 616),
#  (('hillary', 'clinton'), 2237),
#  (('george', 'w'), 924),
#  (('democratic', 'party'), 1979),
#  (('migrant', 'children'), 743),
#  (('bill', 'clinton'), 624),
#  (('x99re', 'going'), 537),
#  (('el', 'salvador'), 988),
#  (('appeals', 'court'), 693),
#  (('former', 'president'), 792),
#  (('https', '://'), 4483),
#  (('six', 'months'), 745),
#  (('illegal', 'immigrants'), 1568),
#  (('one', 'point'), 516),
#  (('agency', 'said'), 504),
#  (('foreign', 'policy'), 1209),
#  (('president', 'mike'), 852),
#  (('mike', 'pence'), 1220),
#  (('hong', 'kong'), 2096),
#  (('next', 'year'), 861),
#  (('second', 'term'), 876),
#  (('said', 'trump'), 570),
#  (('news', 'conference'), 828),
#  (('town', 'hall'), 882),
#  (('new', 'hampshire'), 738),
#  (('american', 'people'), 2056),
#  (('biden', 'also'), 531),
#  (('last', 'night'), 507),
#  (('democratic', 'presidential'), 1770),
#  (('former', 'vice'), 924),
#  (('lindsey', 'graham'), 536),
#  (('likely', 'voters'), 559),
#  (('south', 'carolina'), 1080),
#  (('black', 'women'), 817),
#  (('press', 'secretary'), 558),
#  (('health', 'officials'), 954),
#  (('health', 'care'), 4897),
#  (('affordable', 'care'), 1362),
#  (('care', 'act'), 1373),
#  (('looks', 'like'), 545),
#  (('former', 'vice'), 1524),
#  (('washington', 'post'), 1658),
#  (('york', 'city'), 1602),
#  (('york', 'times'), 1823),
#  (('general', 'election'), 994),
#  (('george', 'floyd'), 864),
#  (('biden', 'campaign'), 1934),
#  (('battleground', 'states'), 1083),
#  (('fox', 'news'), 3371),
#  (('x9d', 'biden'), 975),
#  (('speaker', 'nancy'), 648),
#  (('nancy', 'pelosi'), 960),
#  (('chuck', 'schumer'), 527),
#  (('customs', 'enforcement'), 1254),
#  (('los', 'angeles'), 1841),
#  (('five', 'years'), 786),
#  (('foreign', 'nationals'), 546),
#  (('electoral', 'votes'), 702),
#  (('police', 'officer'), 653),
#  (('black', 'lives'), 1471),
#  (('lives', 'matter'), 1416),
#  (('trump', 'supporters'), 856),
#  (('next', 'week'), 676),
#  (('4', 'million'), 795),
#  (('would', 'like'), 510),
#  (('emmanuel', 'macron'), 541),
#  (('1', 'million'), 870),
#  (('racial', 'justice'), 624),
#  (('real', 'estate'), 585),
#  (('2016', 'election'), 558),
#  (('many', 'people'), 1170),
#  (('federal', 'judge'), 696),
#  (('justice', 'ruth'), 954),
#  (('ruth', 'bader'), 1485),
#  (('bader', 'ginsburg'), 1461),
#  (('leader', 'mitch'), 624),
#  (('mitch', 'mcconnell'), 951),
#  (('abortion', 'rights'), 593),
#  (('senate', 'republicans'), 630),
#  (('house', 'speaker'), 660),
#  (('would', 'also'), 612),
#  (('last', 'four'), 612),
#  (('first', 'woman'), 684),
#  (('republican', 'party'), 1338),
#  (('southern', 'border'), 1038),
#  (('african', 'american'), 722),
#  (('battleground', 'state'), 621),
#  (('senior', 'adviser'), 630),
#  (('american', 'workers'), 623),
#  (('executive', 'director'), 902),
#  (('senate', 'judiciary'), 672),
#  (('judiciary', 'committee'), 1068),
#  (('swing', 'states'), 903),
#  (('roe', 'v'), 522),
#  (('senate', 'majority'), 717),
#  (('majority', 'leader'), 765),
#  (('election', 'day'), 3999),
#  (('presidential', 'campaign'), 822),
#  (('black', 'people'), 942),
#  (('criminal', 'justice'), 780),
#  (('federal', 'government'), 1410),
#  (('law', 'school'), 628),
#  (('african', 'americans'), 679),
#  (('20', 'years'), 690),
#  (('house', 'democrats'), 564),
#  (('health', 'insurance'), 750),
#  (('early', 'voting'), 1027),
#  (('make', 'sure'), 1443),
#  (('justice', 'ginsburg'), 666),
#  (('recent', 'weeks'), 606),
#  (('family', 'members'), 980),
#  (('pope', 'francis'), 691),
#  (('3', 'million'), 894),
#  (('conspiracy', 'theories'), 592),
#  (('every', 'year'), 522),
#  (('oval', 'office'), 579),
#  (('new', 'mexico'), 619),
#  (('san', 'diego'), 704),
#  (('illegal', 'immigration'), 1135),
#  (('black', 'americans'), 611),
#  (('attorney', 'general'), 1259),
#  (('puerto', 'rican'), 753),
#  (('capitol', 'hill'), 578),
#  (('absentee', 'ballots'), 774),
#  (('silicon', 'valley'), 635),
#  (('transition', 'team'), 660),
#  (('fiscal', 'year'), 708),
#  (('state', 'department'), 940),
#  (('minimum', 'wage'), 779),
#  (('election', 'night'), 558),
#  (('campaign', 'trail'), 744),
#  (('amy', 'coney'), 1641),
#  (('coney', 'barrett'), 1690),
#  (('new', 'jersey'), 1451),
#  (('presidential', 'debate'), 2072),
#  (('first', 'presidential'), 564),
#  (('white', 'supremacists'), 549),
#  (('ilhan', 'omar'), 626),
#  (('obama', 'administration'), 1697),
#  (('voter', 'fraud'), 725),
#  (('small', 'businesses'), 510),
#  (('first', 'lady'), 982),
#  (('melania', 'trump'), 609),
#  (('golden', 'dawn'), 1447),
#  (('least', 'one'), 534),
#  (('english', 'channel'), 594),
#  (('come', 'back'), 537),
#  (('harris', 'said'), 517),
#  (('illegal', 'migrants'), 654),
#  (('electoral', 'college'), 666),
#  (('latino', 'voters'), 1923),
#  (('percentage', 'points'), 798),
#  (('green', 'new'), 660),
#  (('new', 'deal'), 789),
#  (('per', 'cent'), 756),
#  (('000', 'votes'), 720),
#  (('democratic', 'nominee'), 991),
#  (('proud', 'boys'), 565),
#  (('nominee', 'joe'), 1104),
#  (('000', 'americans'), 553),
#  (('president', 'biden'), 595),
#  (('nbc', 'news'), 2716),
#  (('million', 'americans'), 582),
#  (('biden', 'administration'), 1392),
#  (('presidential', 'race'), 743),
#  (('registered', 'voters'), 810),
#  (('task', 'force'), 915),
#  (('voter', 'registration'), 774),
#  (('social', 'security'), 782),
#  (('notre', 'dame'), 542),
#  (('samuel', 'paty'), 544),
#  (('charlie', 'hebdo'), 799),
#  (('told', 'fox'), 872),
#  (('american', 'history'), 559),
#  (('exit', 'polls'), 512),
#  (('usa', 'today'), 2565),
#  (('told', 'cnn'), 1365),
#  (('president', 'obama'), 606),
#  (('michelle', 'obama'), 531),
#  (('puerto', 'ricans'), 537),
#  (('hispanic', 'voters'), 742),
#  (('elect', 'joe'), 1282),
#  (('elect', 'kamala'), 597),
#  (('green', 'card'), 528),
#  (('told', 'nbc'), 934),
#  (('patrol', 'agents'), 720),
#  (('breitbart', 'texas'), 1008),
#  (('breitbart', 'news'), 2297),
#  (('—', 'breitbart'), 1034),
#  (('breitbart', 'london'), 2987),
#  (('london', '(@'), 2874),
#  (('(@', 'breitbartlondon'), 2874),
#  (('x94', 'breitbart'), 1551),
#  (('visa', 'workers'), 1086),
#  (('fortune', '500'), 613),
#  (('labor', 'market'), 540),
#  (('john', 'binder'), 654),
#  (('emphasis', 'added'), 504),
#  (('2020', 'election'), 989),
#  (('legal', 'immigration'), 588),
#  (('illegal', 'alien'), 636),
#  (('.-', 'mexico'), 684),
#  (('census', 'bureau'), 990),
#  (('immigration', 'reform'), 696),
#  (('—', '“'), 890),
#  (('cbs', 'news'), 2196),
#  (('president', "\\'"), 522),
#  ((',"', 'said'), 4154),
#  (('c', '.,'), 546),
#  (('america', "\\'"), 552),
#  (('video', 'clip'), 834),
#  (('security', 'adviser'), 594),
#  (('get', 'breaking'), 654),
#  (('breaking', 'news'), 660),
#  (('news', 'delivered'), 654),
#  (('trump', "\\'"), 5825),
#  (('administration', "\\'"), 956),
#  (('nation', "\\'"), 608),
#  (('."\'', 'b'), 752),
#  (('told', 'cbs'), 588),
#  (('state', "\\'"), 1172),
#  (('president', "\\'"), 932),
#  (('."', 'trump'), 626),
#  (('country', "\\'"), 624),
#  ((',"', 'biden'), 666),
#  (('biden', "\\'"), 2800),
#  (('campaign', 'reporter'), 654),
#  (('news', 'campaign'), 630),
#  (('."', 'biden'), 501),
#  (('obama', "\\'"), 760),
#  ((',"', 'trump'), 816),
#  (('harris', "\\'"), 544),
#  (('hide', 'caption'), 3474),
#  (('videos', '...'), 708),
#  (('...', 'must'), 708),
#  (('must', 'watch'), 708),
#  (('427', 'photos'), 2544),
#  (('fox', 'news'), 2796),
#  (('news', 'app'), 2424),
#  (('follow', 'nbc'), 511)]

# %%
# Save as JSON file
with open('intermediate_full_text.json', 'w') as outfile:
    json.dump(text_list, outfile)

# %% [markdown]
# This file was manually cleaned to remove junk words.

# %%
# Reopen cleaned file
with open('intermediate_full_text.json') as f:
      bigrams_cleaned = json.load(f)

print(bigrams_cleaned)
# Out:
# [[['officials', 'said'], 1044], [['also', 'said'], 1056], [['refugee', 'camp'], 580], [['prime', 'minister'], 1784], [['public', 'health'], 2288], [['national', 'security'], 1914], [['last', 'week'], 3202], [['news', 'agency'], 647], [['human', 'rights'], 2279], [['european', 'union'], 1056], [['country', '2019'], 608], [['asylum', 'seekers'], 1673], [['civil', 'rights'], 1268], [['getty', 'images'], 1050], [['social', 'media'], 2863], [['wall', 'street'], 1347], [['street', 'journal'], 539], [['last', 'week'], 561], [['last', 'month'], 1850], [['first', 'time'], 2160], [['tuesday', 'night'], 642], [['associated', 'press'], 1332], [['al', 'jazeera'], 2543], [['police', 'officers'], 853], [['two', 'years'], 1573], [['last', 'year'], 2719], [['donald', 'trump'], 11745], [['joe', 'biden'], 13471], [['trump', '2019'], 3854], [['us', 'president'], 678], [['president', 'donald'], 6731], [['white', 'house'], 9617], [['vice', 'president'], 3885], [['president', 'joe'], 1224], [['presidential', 'election'], 2659], [['november', '3'], 720], [['united', 'states'], 11877], [['coronavirus', 'pandemic'], 3447], [['foreign', 'workers'], 1342], [['green', 'cards'], 1295], [['mexico', 'border'], 1059], [['trump', 'administration'], 6659], [['supreme', 'court'], 10508], [['high', 'court'], 744], [['president', 'barack'], 1758], [['barack', 'obama'], 3212], [['would', 'make'], 742], [['border', 'wall'], 1132], [['central', 'america'], 802], [['border', 'patrol'], 1937], [['rio', 'grande'], 708], [['biden', 'said'], 2265], [['biden', '2019'], 1956], [['border', 'protection'], 779], [['ap', 'photo'], 654], [['executive', 'order'], 852], [['biden', 'would'], 982], [['north', 'korea'], 622], [['undocumented', 'immigrants'], 1679], [['new', 'york'], 8908], [['10', 'years'], 636], [['5', 'million'], 1069], [['million', 'people'], 1395], [['illegal', 'aliens'], 2593], [['voting', 'rights'], 708], [['president', 'trump'], 7332], [['attorney', 'general'], 1145], [['immigration', 'policies'], 1207], [['young', 'people'], 723], [['prime', 'minister'], 631], [['19', 'pandemic'], 1525], [['high', 'school'], 827], [['told', 'al'], 1098], [['tested', 'positive'], 2004], [['two', 'days'], 618], [['south', 'asian'], 867], [['asian', 'americans'], 1578], [['justice', 'department'], 1615], [['pew', 'research'], 612], [['research', 'center'], 574], [['world', 'war'], 678], [['views', 'expressed'], 540], [['homeland', 'security'], 3056], [['nation', '2019'], 640], [['immigration', 'system'], 893], [['immigration', 'policy'], 692], [['middle', 'east'], 1077], [['first', 'black'], 648], [['asian', 'american'], 2028], [['vice', 'president'], 3912], [['vice', 'presidential'], 1140], [['presidential', 'nominee'], 1505], [['four', 'years'], 3846], [['years', 'later'], 797], [['kamala', 'harris'], 3797], [['trump', 'said'], 2712], [['north', 'carolina'], 3123], [['black', 'woman'], 597], [['president', '2019'], 578], [['trump', 'campaign'], 2770], [['black', 'voters'], 854], [['running', 'mate'], 1024], [['law', 'enforcement'], 2634], [['bernie', 'sanders'], 951], [['alexandria', 'ocasio'], 625], [['court', 'justice'], 690], [['presidential', 'candidate'], 1307], [['feel', 'like'], 798], [['told', 'reporters'], 954], [['human', 'rights'], 1005], [['state', '2019'], 712], [['saudi', 'arabia'], 611], [['coronavirus', 'outbreak'], 3024], [['6', 'million'], 654], [['2', 'million'], 921], [['united', 'nations'], 1322], [['novel', 'coronavirus'], 3030], [['disease', 'control'], 694], [['new', 'coronavirus'], 558], [['19', 'cases'], 785], [['coronavirus', 'cases'], 1079], [['new', 'cases'], 760], [['two', 'weeks'], 1368], [['social', 'distancing'], 894], [['7', 'million'], 516], [['every', 'day'], 961], [['years', 'ago'], 3420], [['every', 'single'], 543], [['recent', 'years'], 1062], [['three', 'years'], 1080], [['would', 'allow'], 523], [['climate', 'change'], 2195], [['mental', 'health'], 977], [['san', 'francisco'], 1755], [['puerto', 'rico'], 1069], [['look', 'like'], 721],  ...

# %%
len(bigrams_cleaned)
# Out:
# 357

# %%
bigrams_clean = []

for bigram in bigrams_cleaned:
    if bigram[1] > 1700:
        bigrams_clean.append(bigram)

# %%
# Create list of all words in bigrams
all_words = []

for bigram in bigrams_clean:
    if bigram[0][0] not in all_words:
        all_words.append(bigram[0][0])
    if bigram[0][1] not in all_words:
        all_words.append(bigram[0][1])

# Remove the word 'news' which is a self-reference
all_words.remove('news')
all_words.remove('breitbart')
all_words.remove('fox')
all_words.remove('york')

# Determine which words occur more than once
duplicate_words = []

for word in all_words:
    word_count = 0
    for bigram in bigrams_clean:
        if word == bigram[0][0] or word == bigram[0][1]:
            word_count += 1
    if word_count > 1:
        duplicate_words.append(word)

# Only keep bigrams that contain these words
links = []

for bigram in bigrams_clean:
    if bigram[0][0] in duplicate_words or bigram[0][1] in duplicate_words:
        bigram_dict = {'source': bigram[0][0], 'target': bigram[0][1], 'frequency': bigram[1]}
        links.append(bigram_dict)

len(links)
# Out:
# 34

# %%
links
# Out:
# [{'source': 'public', 'target': 'health', 'frequency': 2288},
#  {'source': 'national', 'target': 'security', 'frequency': 1914},
#  {'source': 'last', 'target': 'week', 'frequency': 3202},
#  {'source': 'last', 'target': 'month', 'frequency': 1850},
#  {'source': 'last', 'target': 'year', 'frequency': 2719},
#  {'source': 'donald', 'target': 'trump', 'frequency': 11745},
#  {'source': 'joe', 'target': 'biden', 'frequency': 13471},
#  {'source': 'trump', 'target': '2019', 'frequency': 3854},
#  {'source': 'president', 'target': 'donald', 'frequency': 6731},
#  {'source': 'vice', 'target': 'president', 'frequency': 3885},
#  {'source': 'presidential', 'target': 'election', 'frequency': 2659},
#  {'source': 'coronavirus', 'target': 'pandemic', 'frequency': 3447},
#  {'source': 'trump', 'target': 'administration', 'frequency': 6659},
#  {'source': 'president', 'target': 'barack', 'frequency': 1758},
#  {'source': 'barack', 'target': 'obama', 'frequency': 3212},
#  {'source': 'biden', 'target': 'said', 'frequency': 2265},
#  {'source': 'biden', 'target': '2019', 'frequency': 1956},
#  {'source': 'president', 'target': 'trump', 'frequency': 7332},
#  {'source': 'homeland', 'target': 'security', 'frequency': 3056},
#  {'source': 'asian', 'target': 'american', 'frequency': 2028},
#  {'source': 'vice', 'target': 'president', 'frequency': 3912},
#  {'source': 'four', 'target': 'years', 'frequency': 3846},
#  {'source': 'trump', 'target': 'said', 'frequency': 2712},
#  {'source': 'trump', 'target': 'campaign', 'frequency': 2770},
#  {'source': 'coronavirus', 'target': 'outbreak', 'frequency': 3024},
#  {'source': 'novel', 'target': 'coronavirus', 'frequency': 3030},
#  {'source': 'years', 'target': 'ago', 'frequency': 3420},
#  {'source': 'democratic', 'target': 'party', 'frequency': 1979},
#  {'source': 'american', 'target': 'people', 'frequency': 2056},
#  {'source': 'democratic', 'target': 'presidential', 'frequency': 1770},
#  {'source': 'health', 'target': 'care', 'frequency': 4897},
#  {'source': 'biden', 'target': 'campaign', 'frequency': 1934},
#  {'source': 'election', 'target': 'day', 'frequency': 3999},
#  {'source': 'presidential', 'target': 'debate', 'frequency': 2072}]

# %%
# Read in pos/negative word lists
pos_words = []
with open('positive_words_en.txt') as p:
    for row in p:
        word = p.readline()
        pos_words.append(word.rstrip())

neg_words = [] 
with open('negative_words_en.txt') as n:
    for row in n:
        word = n.readline()
        neg_words.append(word.rstrip())

# %%
# Create list of words w/ sentiment from bigrams
nodes = []
word_check = []
for bigram in links:
    word_dict = {}
    sentiment = 0
    first_word = bigram['source']
    second_word = bigram['target']

    if first_word not in word_check:
        word_check.append(first_word)
        if first_word in pos_words:
            sentiment = 1
        if first_word in neg_words:
            sentiment = -1
        word_dict = {'id': first_word, 'group': sentiment}
        nodes.append(word_dict)
        
        
    if second_word not in word_check:
        word_check.append(second_word)
        if second_word in pos_words:
            sentiment = 1
        if second_word in neg_words:
            sentiment = -1
        word_dict = {'id': second_word, 'group': sentiment}
        nodes.append(word_dict)

# %%
# Check sentiment labels for accuracy
for word in nodes:
    print(word)
# Out:
# {'id': 'public', 'group': 0}
# {'id': 'health', 'group': 0}
# {'id': 'national', 'group': 0}
# {'id': 'security', 'group': 0}
# {'id': 'last', 'group': 0}
# {'id': 'week', 'group': 0}
# {'id': 'month', 'group': 0}
# {'id': 'year', 'group': 0}
# {'id': 'donald', 'group': 0}
# {'id': 'trump', 'group': 0}
# {'id': 'joe', 'group': 0}
# {'id': 'biden', 'group': 0}
# {'id': '2019', 'group': 0}
# {'id': 'president', 'group': 0}
# {'id': 'vice', 'group': -1}
# {'id': 'presidential', 'group': 0}
# {'id': 'election', 'group': 0}
# {'id': 'coronavirus', 'group': 0}
# {'id': 'pandemic', 'group': 0}
# {'id': 'administration', 'group': 0}
# {'id': 'barack', 'group': 0}
# {'id': 'obama', 'group': 0}
# {'id': 'said', 'group': 0}
# {'id': 'homeland', 'group': 0}
# {'id': 'asian', 'group': 0}
# {'id': 'american', 'group': 0}
# {'id': 'four', 'group': 0}
# {'id': 'years', 'group': 0}
# {'id': 'campaign', 'group': 0}
# {'id': 'outbreak', 'group': -1}
# {'id': 'novel', 'group': 0}
# {'id': 'ago', 'group': 0}
# {'id': 'democratic', 'group': 0}
# {'id': 'party', 'group': 0}
# {'id': 'people', 'group': 0}
# {'id': 'care', 'group': 0}
# {'id': 'day', 'group': 0}
# {'id': 'debate', 'group': 0}

# %%
# Format data for arc diagram
full_text_bigrams = {'nodes': nodes, 'links': links, 'text_source': 'full_text'}

# %%
# Read in headline bigrams
bigrams_data = db.headline_bigrams.find_one({})

bigrams_data.pop('_id')
bigrams_data['text_source'] = 'headlines'

# %%
all_bigrams = [full_text_bigrams, bigrams_data]

# %%
all_bigrams
# Out:
# [{'nodes': [{'id': 'public', 'group': 0},
#    {'id': 'health', 'group': 0},
#    {'id': 'national', 'group': 0},
#    {'id': 'security', 'group': 0},
#    {'id': 'last', 'group': 0},
#    {'id': 'week', 'group': 0},
#    {'id': 'month', 'group': 0},
#    {'id': 'year', 'group': 0},
#    {'id': 'donald', 'group': 0},
#    {'id': 'trump', 'group': 0},
#    {'id': 'joe', 'group': 0},
#    {'id': 'biden', 'group': 0},
#    {'id': '2019', 'group': 0},
#    {'id': 'president', 'group': 0},
#    {'id': 'vice', 'group': -1},
#    {'id': 'presidential', 'group': 0},
#    {'id': 'election', 'group': 0},
#    {'id': 'coronavirus', 'group': 0},
#    {'id': 'pandemic', 'group': 0},
#    {'id': 'administration', 'group': 0},
#    {'id': 'barack', 'group': 0},
#    {'id': 'obama', 'group': 0},
#    {'id': 'said', 'group': 0},
#    {'id': 'homeland', 'group': 0},
#    {'id': 'asian', 'group': 0},
#    {'id': 'american', 'group': 0},
#    {'id': 'four', 'group': 0},
#    {'id': 'years', 'group': 0},
#    {'id': 'campaign', 'group': 0},
#    {'id': 'outbreak', 'group': -1},
#    {'id': 'novel', 'group': 0},
#    {'id': 'ago', 'group': 0},
#    {'id': 'democratic', 'group': 0},
#    {'id': 'party', 'group': 0},
#    {'id': 'people', 'group': 0},
#    {'id': 'care', 'group': 0},
#    {'id': 'day', 'group': 0},
#    {'id': 'debate', 'group': 0}],
#   'links': [{'source': 'public', 'target': 'health', 'frequency': 2288},
#    {'source': 'national', 'target': 'security', 'frequency': 1914},
#    {'source': 'last', 'target': 'week', 'frequency': 3202},
#    {'source': 'last', 'target': 'month', 'frequency': 1850},
#    {'source': 'last', 'target': 'year', 'frequency': 2719},
#    {'source': 'donald', 'target': 'trump', 'frequency': 11745},
#    {'source': 'joe', 'target': 'biden', 'frequency': 13471},
#    {'source': 'trump', 'target': '2019', 'frequency': 3854},
#    {'source': 'president', 'target': 'donald', 'frequency': 6731},
#    {'source': 'vice', 'target': 'president', 'frequency': 3885},
#    {'source': 'presidential', 'target': 'election', 'frequency': 2659},
#    {'source': 'coronavirus', 'target': 'pandemic', 'frequency': 3447},
#    {'source': 'trump', 'target': 'administration', 'frequency': 6659},
#    {'source': 'president', 'target': 'barack', 'frequency': 1758},
#    {'source': 'barack', 'target': 'obama', 'frequency': 3212},
#    {'source': 'biden', 'target': 'said', 'frequency': 2265},
#    {'source': 'biden', 'target': '2019', 'frequency': 1956},
#    {'source': 'president', 'target': 'trump', 'frequency': 7332},
#    {'source': 'homeland', 'target': 'security', 'frequency': 3056},
#    {'source': 'asian', 'target': 'american', 'frequency': 2028},
#    {'source': 'vice', 'target': 'president', 'frequency': 3912},
#    {'source': 'four', 'target': 'years', 'frequency': 3846},
#    {'source': 'trump', 'target': 'said', 'frequency': 2712},
#    {'source': 'trump', 'target': 'campaign', 'frequency': 2770},
#    {'source': 'coronavirus', 'target': 'outbreak', 'frequency': 3024},
#    {'source': 'novel', 'target': 'coronavirus', 'frequency': 3030},
#    {'source': 'years', 'target': 'ago', 'frequency': 3420},
#    {'source': 'democratic', 'target': 'party', 'frequency': 1979},
#    {'source': 'american', 'target': 'people', 'frequency': 2056},
#    {'source': 'democratic', 'target': 'presidential', 'frequency': 1770},
#    {'source': 'health', 'target': 'care', 'frequency': 4897},
#    {'source': 'biden', 'target': 'campaign', 'frequency': 1934},
#    {'source': 'election', 'target': 'day', 'frequency': 3999},
#    {'source': 'presidential', 'target': 'debate', 'frequency': 2072}],
#   'text_source': 'full_text'},
#  {'nodes': [{'id': 'ruth', 'group': 0},
#    {'id': 'bader', 'group': 0},
#    {'id': 'ginsburg', 'group': 0},
#    {'id': 'amy', 'group': 0},
#    {'id': 'coney', 'group': 0},
#    {'id': 'barrett', 'group': 0},
#    {'id': 'wall', 'group': 0},
#    {'id': 'street', 'group': 0},
#    {'id': 'border', 'group': 0},
#    {'id': 'undocumented', 'group': -1},
#    {'id': 'immigrant', 'group': -1},
#    {'id': 'illegal', 'group': -1},
#    {'id': 'alien', 'group': 0},
#    {'id': 'immigration', 'group': 0},
#    {'id': 'migrant', 'group': 0},
#    {'id': 'vp', 'group': 0},
#    {'id': 'debate', 'group': 0},
#    {'id': 'presidential', 'group': 0},
#    {'id': 'patrol', 'group': 0},
#    {'id': 'texas', 'group': 0},
#    {'id': 'election', 'group': 0},
#    {'id': 'asian', 'group': 0},
#    {'id': 'american', 'group': 0},
#    {'id': 'americans', 'group': 0},
#    {'id': 'voter', 'group': 0},
#    {'id': 'refugee', 'group': 0},
#    {'id': 'camp', 'group': 0},
#    {'id': 'caravan', 'group': 0},
#    {'id': 'child', 'group': 0},
#    {'id': 'latino', 'group': 0},
#    {'id': 'policy', 'group': 0},
#    {'id': 'joe', 'group': 0},
#    {'id': 'biden', 'group': 0},
#    {'id': 'win', 'group': 1},
#    {'id': 'trump', 'group': 0},
#    {'id': '2020', 'group': 0},
#    {'id': 'us', 'group': 0},
#    {'id': 'donald', 'group': 0},
#    {'id': 'melania', 'group': 0},
#    {'id': 'administration', 'group': 0},
#    {'id': 'president', 'group': 0},
#    {'id': 'say', 'group': 0}],
#   'links': [{'source': 'ruth', 'target': 'bader', 'value': 11},
#    {'source': 'bader', 'target': 'ginsburg', 'value': 10},
#    {'source': 'amy', 'target': 'coney', 'value': 10},
#    {'source': 'coney', 'target': 'barrett', 'value': 10},
#    {'source': 'wall', 'target': 'street', 'value': 10},
#    {'source': 'border', 'target': 'wall', 'value': 7},
#    {'source': 'undocumented', 'target': 'immigrant', 'value': 9},
#    {'source': 'illegal', 'target': 'immigrant', 'value': 6},
#    {'source': 'illegal', 'target': 'alien', 'value': 8},
#    {'source': 'illegal', 'target': 'immigrant', 'value': 6},
#    {'source': 'illegal', 'target': 'immigration', 'value': 5},
#    {'source': 'illegal', 'target': 'migrant', 'value': 5},
#    {'source': 'vp', 'target': 'debate', 'value': 8},
#    {'source': 'presidential', 'target': 'debate', 'value': 8},
#    {'source': 'border', 'target': 'patrol', 'value': 8},
#    {'source': 'border', 'target': 'wall', 'value': 7},
#    {'source': 'texas', 'target': 'border', 'value': 5},
#    {'source': 'presidential', 'target': 'debate', 'value': 8},
#    {'source': 'presidential', 'target': 'election', 'value': 6},
#    {'source': 'asian', 'target': 'american', 'value': 8},
#    {'source': 'asian', 'target': 'americans', 'value': 7},
#    {'source': 'asian', 'target': 'american', 'value': 8},
#    {'source': 'american', 'target': 'voter', 'value': 6},
#    {'source': 'refugee', 'target': 'camp', 'value': 7},
#    {'source': 'migrant', 'target': 'camp', 'value': 6},
#    {'source': 'migrant', 'target': 'caravan', 'value': 7},
#    {'source': 'migrant', 'target': 'camp', 'value': 6},
#    {'source': 'migrant', 'target': 'child', 'value': 5},
#    {'source': 'illegal', 'target': 'migrant', 'value': 5},
#    {'source': 'latino', 'target': 'voter', 'value': 7},
#    {'source': 'american', 'target': 'voter', 'value': 6},
#    {'source': 'immigration', 'target': 'policy', 'value': 7},
#    {'source': 'illegal', 'target': 'immigration', 'value': 5},
#    {'source': 'joe', 'target': 'biden', 'value': 6},
#    {'source': 'biden', 'target': 'win', 'value': 4},
#    {'source': 'trump', 'target': 'biden', 'value': 1},
#    {'source': 'presidential', 'target': 'election', 'value': 6},
#    {'source': '2020', 'target': 'election', 'value': 6},
#    {'source': 'us', 'target': 'election', 'value': 5},
#    {'source': 'donald', 'target': 'trump', 'value': 6},
#    {'source': 'melania', 'target': 'trump', 'value': 6},
#    {'source': 'trump', 'target': 'administration', 'value': 6},
#    {'source': 'president', 'target': 'trump', 'value': 4},
#    {'source': 'say', 'target': 'trump', 'value': 2},
#    {'source': 'trump', 'target': 'say', 'value': 2},
#    {'source': 'trump', 'target': 'biden', 'value': 1},
#    {'source': 'say', 'target': 'trump', 'value': 2},
#    {'source': 'trump', 'target': 'say', 'value': 2}],
#   'text_source': 'headlines'}]

# %%
# Save as JSON file
with open('all_bigrams.json', 'w') as outfile:
    json.dump(all_bigrams, outfile)
