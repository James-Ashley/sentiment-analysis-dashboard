# %% [markdown]
# ## References
# * https://medium.com/@nicharuch/collocations-identifying-phrases-that-act-like-individual-words-in-nlp-f58a93a2f84a
# * Sentiment Lexicons: https://sites.google.com/site/datascienceslab/projects/multilingualsentiment

# %%
# Dependencies
import pymongo
import os
from dotenv import load_dotenv
import spacy
import re
import string
import nltk
from nltk.corpus import stopwords

# %%
# Load in database access info
load_dotenv()
username = os.getenv("db_username")
password = os.getenv("db_password")

# %%
# Connect to database
conn = f"mongodb+srv://{username}:{password}@clusterprime.mpaq0.mongodb.net/ETL?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.ETL

# %%
# Pull all data from collection
news_data = db.NFTA.find({})

# %%
# Store headlines in list
headlines = []
for article in news_data:
    headlines.append(article['title'])
print(headlines)
# Out:
# ['I could be deported because my parents came here legally. Biden can change that.', "First Latino tapped to head DHS signals shift from Trump's hard-line immigration policies", 'Tony Pham, interim director of Immigration and Customs Enforcement, to step down', 'More than two-thirds of undocumented immigrant workers have jobs "essential" to Covid fight, says study', 'Biden to meet with struggling workers, small-business owners about the economic crisis - NBC News', 'Accused hate groups receive pandemic aid', 'Lawyers say Trump admin has handed over data that will help reunite separated migrant families', '28 migrant children and their parents face deportation after refusing to be separated', 'Visa delays leave thousands of South Asian women unable to work', 'Advocates, mental health experts pressure Biden to commit to reuniting separated families in the U.S.', "U.K.'s first non-white leader? Finance minister Sunak wins praise for staying calm in a crisis", '12 great Latino books of 2020', "Feinstein says she's stepping down as top Democrat on Senate Judiciary Committee", 'Judge throws out Trump rules limiting skilled-worker visas', 'San Francisco officer who seriously injured suspect indicted', 'Latino Catholics commemorate Virgen de Guadalupe through virtual events, amid Covid', 'In Covid-19 regulations case, Sotomayor dissent claps back at Supreme Court majority', 'Pope installs new cardinals, including first African-American', "Why Trump's immigration legacy could take time to undo", 'Trump administration settles lawsuit from U.S. Latinas detained after speaking Spanish', "From Covid-19 to racial justice, how 2020's biggest issues influenced the Black vote", 'Almost a year after the pandemic began, 35,000 Australians remain stranded abroad', 'The democracy hangs on — by just enough', "Mexico's president one of last world leaders to formally congratulate Biden", 'Lawmakers demand Biden include Asian Americans, Pacific Islanders in Cabinet', 'Biden looks to Susan Rice to elevate low-profile Domestic Policy Council', "Trump's tortured census power grab seems destined to fail. The question is: When?", 'Covid job losses are devastating these workers, who are largely unseen', 'Federal judge reinstates DACA, orders Homeland Security to quickly accept new applicants', 'Did Trump draw out a new Latino Republican voter bloc in Florida?', 'Who will replace Kamala Harris in the U.S. Senate? California governor weighs a shortlist of firsts', 'How Dems are engaging these 1st-time voters who helped flip GOP district', "How the pandemic threatens to destroy America's three remaining Japantowns", "'No choice except to flee': After back-to-back hurricanes, Central Americans go north", "Member of Hungary's anti-LGBTQ government resigns after fleeing alleged sex party", 'Dozens rescued in smuggling operation, Houston police say', 'Driver arrested after plowing into New York City protesters, injuring 6', 'Bypassing McConnell: Democrats push Biden to aggressively use executive power', 'Supreme Court puts off ruling on Trump census case to exclude undocumented immigrants', 'Bipartisan group of senators seek compromise on a Covid-19 relief package', "Biden meets, outpaces Trump and Obama's Cabinet nomination timelines", 'Iowa congressional race likely to be one of closest in modern history', "Supreme Court skeptical of Trump's plan to exclude undocumented immigrants from census", 'Supreme Court set to hear arguments on Trump plan to exclude undocumented immigrants from census', 'Modeling agent Jean Luc Brunel arrested in Paris in Epstein probe', "Trump's false fraud claims are laying groundwork for new voting restrictions, experts warn", 'Mental health care has become even more crucial in 2020 — but resources are stretched thin', "Trump is trying to overturn an election but we didn't get here by accident", 'Despite pandemic, a pop-up school for U.S. asylum seekers is seeing success', 'Latino mistrust of Covid vaccine worries Hispanic doctors', 'Bi ...

# %%
# Load spacy
nlp = spacy.load('en_core_web_sm')

# Function to clean and lemmatize comments
def clean_comments(text):
    #remove punctuations
    regex = re.compile('[' + re.escape(string.punctuation) + '\\r\\t\\n]')
    nopunct = regex.sub("", str(text))
    #use spacy to lemmatize comments
    doc = nlp(nopunct, disable=['parser','ner'])
    lemma = [token.lemma_ for token in doc]
    return lemma

# Apply function to clean and lemmatize comments
lemmatized = clean_comments(headlines)

# Make all words lowercase
lemmatized_headlines_1 = [word.lower() for word in lemmatized]

# %%
# Lemmatize word "aliens" - missed by spacy
headlines_clean = []
for word in lemmatized_headlines_1:
    if word == 'aliens':
        headlines_clean.append('alien')
    else:
        headlines_clean.append(word)
headlines_clean
# Out:
# ['-pron-',
#  'could',
#  'be',
#  'deport',
#  'because',
#  '-pron-',
#  'parent',
#  'come',
#  'here',
#  'legally',
#  'biden',
#  'can',
#  'change',
#  'that',
#  'first',
#  'latino',
#  'tap',
#  'to',
#  'head',
#  'dhs',
#  'signal',
#  'shift',
#  'from',
#  'trumps',
#  'hardline',
#  'immigration',
#  'policy',
#  'tony',
#  'pham',
#  'interim',
#  'director',
#  'of',
#  'immigration',
#  'and',
#  'customs',
#  'enforcement',
#  'to',
#  'step',
#  'down',
#  'more',
#  'than',
#  'twothird',
#  'of',
#  'undocumented',
#  'immigrant',
#  'worker',
#  'have',
#  'job',
#  'essential',
#  'to',
#  'covid',
#  'fight',
#  'say',
#  'study',
#  'biden',
#  'to',
#  'meet',
#  'with',
#  'struggle',
#  'worker',
#  'smallbusiness',
#  'owner',
#  'about',
#  'the',
#  'economic',
#  'crisis',
#  ' ',
#  'nbc',
#  'news',
#  'accused',
#  'hate',
#  'group',
#  'receive',
#  'pandemic',
#  'aid',
#  'lawyer',
#  'say',
#  'trump',
#  'admin',
#  'have',
#  'hand',
#  'over',
#  'datum',
#  'that',
#  'will',
#  'help',
#  'reunite',
#  'separate',
#  'migrant',
#  'family',
#  '28',
#  'migrant',
#  'child',
#  'and',
#  '-pron-',
#  'parent',
#  'face',
#  'deportation',
#  'after',
#  'refuse',
#  'to',
#  'be',
#  'separate',
#  'visa',
#  'delay',
#  'leave',
#  'thousand',
#  'of',
#  'south',
#  'asian',
#  'woman',
#  'unable',
#  'to',
#  'work',
#  'advocate',
#  'mental',
#  'health',
#  'expert',
#  'pressure',
#  'biden',
#  'to',
#  'commit',
#  'to',
#  'reunite',
#  'separated',
#  'family',
#  'in',
#  'the',
#  'us',
#  'uks',
#  'first',
#  'nonwhite',
#  'leader',
#  'finance',
#  'minister',
#  'sunak',
#  'win',
#  'praise',
#  'for',
#  'stay',
#  'calm',
#  'in',
#  'a',
#  'crisis',
#  '12',
#  'great',
#  'latino',
#  'book',
#  'of',
#  '2020',
#  'feinstein',
#  'say',
#  '-pron-',
#  's',
#  'step',
#  'down',
#  'as',
#  'top',
#  'democrat',
#  'on',
#  'senate',
#  'judiciary',
#  'committee',
#  'judge',
#  'throw',
#  'out',
#  'trump',
#  'rule',
#  'limit',
#  'skilledworker',
#  'visa',
#  'san',
#  'francisco',
#  'officer',
#  'who',
#  'seriously',
#  'injure',
#  'suspect',
#  'indict',
#  'latino',
#  'catholics',
#  'commemorate',
#  'virgen',
#  'de',
#  'guadalupe',
#  'through',
#  'virtual',
#  'event',
#  'amid',
#  'covid',
#  'in',
#  'covid19',
#  'regulation',
#  'case',
#  'sotomayor',
#  'dissent',
#  'clap',
#  'back',
#  'at',
#  'supreme',
#  'court',
#  'majority',
#  'pope',
#  'install',
#  'new',
#  'cardinal',
#  'include',
#  'first',
#  'africanamerican',
#  'why',
#  'trumps',
#  'immigration',
#  'legacy',
#  'could',
#  'take',
#  'time',
#  'to',
#  'undo',
#  'trump',
#  'administration',
#  'settle',
#  'lawsuit',
#  'from',
#  'us',
#  'latinas',
#  'detain',
#  'after',
#  'speak',
#  'spanish',
#  'from',
#  'covid19',
#  'to',
#  'racial',
#  'justice',
#  'how',
#  '2020s',
#  'big',
#  'issue',
#  'influence',
#  'the',
#  'black',
#  'vote',
#  'almost',
#  'a',
#  'year',
#  'after',
#  'the',
#  'pandemic',
#  'begin',
#  '35000',
#  'australians',
#  'remain',
#  'stranded',
#  'abroad',
#  'the',
#  'democracy',
#  'hang',
#  'on',
#  '—',
#  'by',
#  'just',
#  'enough',
#  'mexicos',
#  'president',
#  'one',
#  'of',
#  'last',
#  'world',
#  'leader',
#  'to',
#  'formally',
#  'congratulate',
#  'biden',
#  'lawmakers',
#  'demand',
#  'biden',
#  'include',
#  'asian',
#  'americans',
#  'pacific',
#  'islanders',
#  'in',
#  'cabinet',
#  'biden',
#  'look',
#  'to',
#  'susan',
#  'rice',
#  'to',
#  'elevate',
#  'lowprofile',
#  'domestic',
#  'policy',
#  'council',
#  'trumps',
#  'torture',
#  'census',
#  'power',
#  'grab',
#  'seem',
#  'destine',
#  'to',
#  'fail',
#  'the',
#  'question',
#  'be',
#  'when',
#  'covid',
#  'job',
#  'loss',
#  'be',
#  'devastate',
#  'these',
#  'worker',
#  'who',
#  'be',
#  'largely',
#  'unseen',
#  'federal',
#  'judge',
#  'reinstate',
#  'daca',
#  'order',
#  'homeland',
#  'security',
#  'to',
#  'quickly',
#  'accept',
#  'new',
#  'applicant',
#  'do',
#  'trump',
#  'draw',
#  'out',
#  'a',
#  'new',
#  'latino',
#  'republican',
#  'voter',
#  'bloc',
#  'in',
#  'florida',
#  'who',
#  'will',
#  'replace',
#  'kamala',
#  'harris',
#  'in',
#  'the',
#  'us',
#  'senate',
#  'california',
#  'governor',
#  'weigh',
#  'a',
#  'shortlist',
#  'of',
#  'first',
#  'how',
#  'dems',
#  'be',
#  'engage',
#  'these',
#  '1sttime',
#  'voter',
#  'who',
#  'help',
#  'flip',
#  'gop',
#  'district',
#  'how',
#  'the',
#  'pandemic',
#  'threaten',
#  'to',
#  'destroy',
#  'americas',
#  'three',
#  'remain',
#  'japantowns',
#  'no',
#  'choice',
#  'except',
#  'to',
#  'flee',
#  'after',
#  'backtoback',
#  'hurricane',
#  'central',
#  'americans',
#  'go',
#  'north',
#  'member',
#  'of',
#  'hungarys',
#  'antilgbtq',
#  'government',
#  'resign',
#  'after',
#  'flee',
#  'allege',
#  'sex',
#  'party',
#  'dozen',
#  'rescue',
#  'in',
#  'smuggling',
#  'operation',
#  'houston',
#  'police',
#  'say',
#  'driver',
#  'arrest',
#  'after',
#  'plow',
#  'into',
#  'new',
#  'york',
#  'city',
#  'protester',
#  'injure',
#  '6',
#  'bypassing',
#  'mcconnell',
#  'democrats',
#  'push',
#  'biden',
#  'to',
#  'aggressively',
#  'use',
#  'executive',
#  'power',
#  'supreme',
#  'court',
#  'put',
#  'off',
#  'rule',
#  'on',
#  'trump',
#  'census',
#  'case',
#  'to',
#  'exclude',
#  'undocumented',
#  'immigrant',
#  'bipartisan',
#  'group',
#  'of',
#  'senator',
#  'seek',
#  'compromise',
#  'on',
#  'a',
#  'covid19',
#  'relief',
#  'package',
#  'biden',
#  'meet',
#  'outpace',
#  'trump',
#  'and',
#  'obamas',
#  'cabinet',
#  'nomination',
#  'timeline',
#  'iowa',
#  'congressional',
#  'race',
#  'likely',
#  'to',
#  'be',
#  'one',
#  'of',
#  'close',
#  'in',
#  'modern',
#  'history',
#  'supreme',
#  'court',
#  'skeptical',
#  'of',
#  'trumps',
#  'plan',
#  'to',
#  'exclude',
#  'undocumented',
#  'immigrant',
#  'from',
#  'census',
#  'supreme',
#  'court',
#  'set',
#  'to',
#  'hear',
#  'argument',
#  'on',
#  'trump',
#  'plan',
#  'to',
#  'exclude',
#  'undocumented',
#  'immigrant',
#  'from',
#  'census',
#  'modeling',
#  'agent',
#  'jean',
#  'luc',
#  'brunel',
#  'arrest',
#  'in',
#  'paris',
#  'in',
#  'epstein',
#  'probe',
#  'trumps',
#  'false',
#  'fraud',
#  'claim',
#  'be',
#  'lay',
#  'groundwork',
#  'for',
#  'new',
#  'voting',
#  'restriction',
#  'expert',
#  'warn',
#  'mental',
#  'health',
#  'care',
#  'have',
#  'become',
#  'even',
#  'more',
#  'crucial',
#  'in',
#  '2020',
#  '—',
#  'but',
#  'resource',
#  'be',
#  'stretch',
#  'thin',
#  'trump',
#  'be',
#  'try',
#  'to',
#  'overturn',
#  'an',
#  'election',
#  'but',
#  '-pron-',
#  'do',
#  'not',
#  'get',
#  'here',
#  'by',
#  'accident',
#  'despite',
#  'pandemic',
#  'a',
#  'popup',
#  'school',
#  'for',
#  'us',
#  'asylum',
#  'seeker',
#  'be',
#  'see',
#  'success',
#  'latino',
#  'mistrust',
#  'of',
#  'covid',
#  'vaccine',
#  'worry',
#  'hispanic',
#  'doctor',
#  'biden',
#  'administration',
#  'on',
#  'track',
#  'to',
#  'be',
#  'most',
#  'lgbtqinclusive',
#  'in',
#  'us',
#  'history',
#  'some',
#  'senate',
#  'democrats',
#  'question',
#  'durbins',
#  'bid',
#  'to',
#  'helm',
#  'judiciary',
#  'committee',
#  'top',
#  'georgia',
#  'republican',
#  'official',
#  'buck',
#  'trumps',
#  'call',
#  'to',
#  'push',
#  'legislator',
#  'to',
#  'overturn',
#  'biden',
#  'victory',
#  'a',
#  'huge',
#  'catastrophe',
#  'democrats',
#  'grapple',
#  'with',
#  'congressional',
#  'and',
#  'state',
#  'election',
#  'loss',
#  'calls',
#  'caravan',
#  'cartoon',
#  'groups',
#  'target',
#  'georgia',
#  'latinos',
#  'ahead',
#  'of',
#  'senate',
#  'runoff',
#  'judi',
#  'ketteler',
#  'trump',
#  'covid19',
#  'and',
#  'racism',
#  'teach',
#  '-pron-',
#  'to',
#  'stop',
#  'be',
#  'nice',
#  'and',
#  'embrace',
#  '-pron-',
#  'rage',
#  'paper',
#  'beat',
#  'app',
#  'vaccine',
#  'verification',
#  'will',
#  'likely',
#  'be',
#  'prove',
#  'offline',
#  'here',
#  'why',
#  'perdue',
#  'ossoff',
#  'race',
#  'slate',
#  'to',
#  'be',
#  'most',
#  'expensive',
#  'senate',
#  'race',
#  'in',
#  'ad',
#  'spend',
#  'new',
#  'campaign',
#  'filing',
#  'show',
#  'trumps',
#  'fundraising',
#  'haul',
#  'off',
#  'claim',
#  'of',
#  'voter',
#  'fraud',
#  'acclaimed',
#  'journalist',
#  'maria',
#  'hinojosa',
#  'lay',
#  '-pron-',
#  'all',
#  'out',
#  'in',
#  '-pron-',
#  'memoir',
#  '—',
#  'and',
#  '-pron-',
#  'resonate',
#  'now',
#  'that',
#  '-pron-',
#  'have',
#  'a',
#  'covid',
#  'vaccine',
#  '-pron-',
#  'can',
#  'not',
#  'let',
#  'immigration',
#  'politic',
#  'trump',
#  'public',
#  'health',
#  'clyburn',
#  'to',
#  'lead',
#  'biden',
#  'inaugural',
#  'committee',
#  'alongside',
#  'new',
#  'cochair',
#  'tsa',
#  'screen',
#  'high',
#  'number',
#  'of',
#  'traveler',
#  'since',
#  'march',
#  'congress',
#  'return',
#  'to',
#  'face',
#  'funding',
#  'deadline',
#  'pressure',
#  'on',
#  'coronavirus',
#  'aid',
#  'englands',
#  'covid19',
#  'infection',
#  'down',
#  '30',
#  'percent',
#  'during',
#  'national',
#  'lockdown',
#  'study',
#  'show',
#  'cashstrapped',
#  'ambulance',
#  'service',
#  'to',
#  'receive',
#  'federal',
#  'aid',
#  'outbreak',
#  'sicken',
#  'staffer',
#  'at',
#  'county',
#  'health',
#  'department',
#  'in',
#  'arizona',
#  'interior',
#  'secretary',
#  'bernhardt',
#  'test',
#  'positive',
#  'penny',
#  'to',
#  'publicly',
#  'receive',
#  'covid',
#  'vaccine',
#  'on',
#  'friday',
#  'biden',
#  'as',
#  'soon',
#  'as',
#  'next',
#  'week',
#  'pope',
#  'francis',
#  'lament',
#  'unprecedented',
#  'educational',
#  'crisis',
#  'cause',
#  'by',
#  'covid',
#  'los',
#  'angeles',
#  'county',
#  'report',
#  'staggering',
#  '21000',
#  'new',
#  'case',
#  'first',
#  'severe',
#  'reaction',
#  'to',
#  'vaccine',
#  'report',
#  'in',
#  'us',
#  'us',
#  'see',
#  'deadly',
#  'day',
#  'of',
#  'pandemic',
#  'yet',
#  'with',
#  'nearly',
#  '3300',
#  'death',
#  'study',
#  '69',
#  'of',
#  'undocumented',
#  'immigrant',
#  'worker',
#  'essential',
#  'to',
#  'fight',
#  'virus',
#  'health',
#  'expert',
#  'warn',
#  'of',
#  'potential',
#  'covid19',
#  'vaccine',
#  'scam',
#  'phone',
#  'call',
#  'tyson',
#  'fire',
#  '7',
#  'manager',
#  'at',
#  'iowa',
#  'plant',
#  'after',
#  'virus',
#  'betting',
#  'investigation',
#  'st',
#  'louis',
#  'doctor',
#  'say',
#  'hospital',
#  'out',
#  'of',
#  'capacity',
#  'or',
#  'be',
#  'at',
#  'capacity',
#  'biden',
#  'distance',
#  '-pron-',
#  'from',
#  'obama',
#  'amid',
#  'third',
#  'term',
#  'comparison',
#  ' ',
#  'fox',
#  'news',
#  'biden',
#  'say',
#  'hell',
#  'push',
#  'pathway',
#  'to',
#  'citizenship',
#  'for',
#  'over',
#  '11',
#  'million',
#  'undocumented',
#  'people',
#  'in',
#  'first',
#  '100',
#  'day',
#  ' ',
#  'fox',
#  'news',
#  'sen',
#  'cotton',
#  'say',
#  'biden',
#  '’s',
#  'cabinet',
#  'pick',
#  'signal',
#  'return',
#  'of',
#  'obamas',
#  "'",
#  'disastrous',
#  "'",
#  'foreign',
#  'policy',
#  ' ',
#  'fox',
#  'news',
#  'blm',
#  'raise',
#  '500',
#  'k',
#  'to',
#  'back',
#  'ossoff',
#  'warnock',
#  'in',
#  'georgia',
#  'senate',
#  'race',
#  ' ',
#  'fox',
#  'news',
#  'james',
#  'carafano',
#  'if',
#  'biden',
#  'pursue',
#  'openborder',
#  'policy',
#  '-pron-',
#  'will',
#  'pose',
#  'grave',
#  'public',
#  'health',
#  'risk',
#  'during',
#  'pandemic',
#  'flashback',
#  'biden',
#  'praise',
#  "'",
#  'constant',
#  'unrelenting',
#  "'",
#  'stream',
#  'of',
#  'immigration',
#  'into',
#  'us',
#  'live',
#  'updates',
#  'georgia',
#  'democrat',
#  'ossoff',
#  'say',
#  'ice',
#  'should',
#  'enforce',
#  'workplace',
#  'protection',
#  'for',
#  'illegal',
#  'immigrant',
#  'new',
#  'york',
#  'gov',
#  'cuomo',
#  'sign',
#  'protect',
#  '-pron-',
#  'courts',
#  'act',
#  'prohibit',
#  'ice',
#  'from',
#  'make',
#  'arrest',
#  'in',
#  'state',
#  'courthouse',
#  'ice',
#  'chief',
#  'tony',
#  ...]

# %%
# Calculate bigrams
bigrams = nltk.collocations.BigramAssocMeasures()

bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(headlines_clean)

# %%
# Limit bigrams to at least 10 occurrences
bigramFinder.apply_freq_filter(10)

# Pull out bigrams and PMI scores
headline_bigrams = list(bigramFinder.score_ngrams(bigrams.pmi))
print(headline_bigrams)
# Out:
# [(('ilhan', 'omar'), 11.245711148410681), (('hong', 'kong'), 11.152601744019199), (('ruth', 'bader'), 10.982676742576889), (('north', 'carolina'), 10.84274648143241), (('town', 'hall'), 10.387066997656222), (('fact', 'check'), 10.36600538212839), (('pope', 'francis'), 10.294620748891628), (('bader', 'ginsburg'), 10.134679836021936), (('fox', 'news'), 10.108207624660746), (('amy', 'coney'), 9.760284321240439), (('coney', 'barrett'), 9.612185682251306), (('washington', 'post'), 9.608281227795388), (('wall', 'street'), 9.567639243298043), (('5', 'thing'), 9.446623842336676), (('terror', 'attack'), 8.720249659438187), (('health', 'care'), 8.69590509310314), (('undocumented', 'immigrant'), 8.644807103820504), (('kamala', 'harris'), 8.545271430269587), (('illegal', 'alien'), 8.38504783001957), (('supreme', 'court'), 8.167452134490183), (('new', 'york'), 8.054569661058673), (('vp', 'debate'), 8.013050391620405), (('border', 'patrol'), 7.9826767425768885), (('white', 'house'), 7.9153917832641785), (('presidential', 'debate'), 7.783568545497637), (('asian', 'american'), 7.754570670046045), (('battleground', 'state'), 7.754570670046045), (('know', 'about'), 7.620106663192182), (('more', 'than'), 7.570806522376728), (('asian', 'americans'), 7.147913098225569), (('refugee', 'camp'), 7.11532935377293), (('migrant', 'caravan'), 7.096333524372454), (('border', 'wall'), 7.070139583827228), (('near', 'border'), 6.98267674257689), (('do', 'not'), 6.85943264211326), (('charge', 'with'), 6.717973516382473), (('latino', 'voter'), 6.671719765510527), (('immigration', 'policy'), 6.567639243298045), (('joe', 'biden'), 6.416138311505533), (('can', 'not'), 6.325750646335798), (('american', 'voter'), 6.022317203229161), (('mean', 'for'), 5.8975731742004704), (('migrant', 'camp'), 5.886880158743505), (('illegal', 'immigrant'), 5.885815203324297), (('presidential', 'election'), 5.749783461804983), (('donald', 'trump'), 5.742395034582472), (('2020', 'election'), 5.677374966276934), (('melania', 'trump'), 5.624769350583957), (('trump', 'administration'), 5.591602486648757), (('ahead', 'of'), 5.475469399370175), (('texas', 'border'), 5.4466238423366775), (('accuse', 'of'), 5.305544397927864), (('the', 'washington'), 5.220263942450254), (('migrant', 'child'), 5.213690475010614), (('role', 'in'), 5.137566898523865), (('will', 'not'), 5.126078301499435), (('illegal', 'immigration'), 5.101664778793975), (('try', 'to'), 5.009856467267671), (('to', 'know'), 4.932688606745209), (('warn', 'of'), 4.839880825579053), (('call', 'for'), 4.816653178816903), (('thing', 'to'), 4.766585316255306), (('know', 'for'), 4.735516416091496), (('us', 'election'), 4.679323238066456), (('the', 'world'), 4.6390535765902055), (('be', 'still'), 4.631655736169195), (('-pron-', 'need'), 4.580493683956872), (('illegal', 'migrant'), 4.52142468831522), (('to', 'hear'), 4.466714142241143), (('-pron-', 's'), 4.342994370230217), (('should', 'be'), 4.336199852643027), ((' ', 'the'), 4.327179146366765), (('if', '-pron-'), 4.280933402097963), (('in', 'texas'), 4.212471707537754), (('history', 'of'), 4.180013515844005), (('in', 'florida'), 4.141535800726809), (('vote', 'for'), 4.1222794613751645), (('out', 'of'), 4.083151976591418), (('biden', 'win'), 4.072183910288173), (('need', 'to'), 4.071784216410872), (('want', 'to'), 4.009856467267669), (('move', 'to'), 3.969214482770324), (('this', 'be'), 3.9592303941977), (('president', 'trump'), 3.9488459120498973), (('be', 'an'), 3.9423565756333065), (('trump', '’s'), 3.8818392235531505), (('biden', '’s'), 3.857896538588779), (('in', 'california'), 3.833413505364481), (('-pron-', 'can'), 3.828421197400459), (('set', 'to'), 3.799289481328012), (('in', 'france'), 3.793612497306505), (('but', '-pron-'), 3.7580318695090593), (('to', 'end'), 3.691680507241415), (('what', '-pron-'), 3.687939973850627), (('the', 'pandemic'), 3.5681872458705612), (('to', 'fight'), 3.5598235466326233), (('arrest', 'in'), 3.5379576218383093), (('—', 'and'), 3.4200103080541915), (( ...

# %%
# Get english stopwords
en_stopwords = set(stopwords.words('english'))

# Function to filter for ADJ/NN bigrams
def rightTypes(ngram):
    if '-pron-' in ngram or 't' in ngram:
        return False
    for word in ngram:
        if word in en_stopwords or word.isspace():
            return False
    acceptable_types = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    second_type = ('NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in acceptable_types and tags[1][1] in second_type:
        return True
    else:
        return False

# Filter bigrams
filtered_headlines = [bigram for bigram in headline_bigrams if rightTypes(bigram[0])]

# %%
# Review filtered bigrams
filtered_headlines
# Out:
# [(('ilhan', 'omar'), 11.245711148410681),
#  (('hong', 'kong'), 11.152601744019199),
#  (('ruth', 'bader'), 10.982676742576889),
#  (('north', 'carolina'), 10.84274648143241),
#  (('town', 'hall'), 10.387066997656222),
#  (('pope', 'francis'), 10.294620748891628),
#  (('bader', 'ginsburg'), 10.134679836021936),
#  (('fox', 'news'), 10.108207624660746),
#  (('amy', 'coney'), 9.760284321240439),
#  (('coney', 'barrett'), 9.612185682251306),
#  (('washington', 'post'), 9.608281227795388),
#  (('wall', 'street'), 9.567639243298043),
#  (('terror', 'attack'), 8.720249659438187),
#  (('health', 'care'), 8.69590509310314),
#  (('undocumented', 'immigrant'), 8.644807103820504),
#  (('illegal', 'alien'), 8.38504783001957),
#  (('supreme', 'court'), 8.167452134490183),
#  (('new', 'york'), 8.054569661058673),
#  (('vp', 'debate'), 8.013050391620405),
#  (('border', 'patrol'), 7.9826767425768885),
#  (('white', 'house'), 7.9153917832641785),
#  (('presidential', 'debate'), 7.783568545497637),
#  (('battleground', 'state'), 7.754570670046045),
#  (('asian', 'americans'), 7.147913098225569),
#  (('refugee', 'camp'), 7.11532935377293),
#  (('migrant', 'caravan'), 7.096333524372454),
#  (('border', 'wall'), 7.070139583827228),
#  (('latino', 'voter'), 6.671719765510527),
#  (('immigration', 'policy'), 6.567639243298045),
#  (('joe', 'biden'), 6.416138311505533),
#  (('american', 'voter'), 6.022317203229161),
#  (('migrant', 'camp'), 5.886880158743505),
#  (('illegal', 'immigrant'), 5.885815203324297),
#  (('presidential', 'election'), 5.749783461804983),
#  (('donald', 'trump'), 5.742395034582472),
#  (('melania', 'trump'), 5.624769350583957),
#  (('trump', 'administration'), 5.591602486648757),
#  (('texas', 'border'), 5.4466238423366775),
#  (('migrant', 'child'), 5.213690475010614),
#  (('illegal', 'immigration'), 5.101664778793975),
#  (('illegal', 'migrant'), 4.52142468831522),
#  (('biden', 'win'), 4.072183910288173),
#  (('president', 'trump'), 3.9488459120498973),
#  (('trump', '’s'), 3.8818392235531505),
#  (('biden', '’s'), 3.857896538588779),
#  (('trump', 'biden'), 1.2321248231578608)]

# %%
# Read in pos/negative word lists

pos_words = []
with open('positive_words_en.txt') as p:
    for row in p:
        word = p.readline()
        pos_words.append(word.rstrip())

neg_words = [] 
with open('negative_words_en.txt') as n:
    for row in n:
        word = n.readline()
        neg_words.append(word.rstrip())
# Out:
# ['death', 'issue', 'killed', 'problems', 'problem', 'lies', 'loss', 'fall', 'lack', 'attacks', 'dead', 'break', 'fell', 'critical', 'unknown', 'fiction', 'enemy', 'opposition', 'losing', 'broke', 'bad', 'crime', 'kill', 'failure', 'critics', 'cancer', 'broken', 'wrong', 'concerns', 'controversial', 'fictional', 'criticism', 'limit', 'strike', 'vice', 'die', 'concerned', 'damaged', 'unusual', 'slow', 'defensive', 'struck', 'cold', 'rival', 'wild', 'losses', 'suicide', 'emergency', 'destruction', 'struggle', 'lose', 'absence', 'limits', 'impossible', 'fear', 'destroy', 'assault', 'missed', 'confused', 'falling', 'protest', 'unsuccessful', 'pain', 'slowly', 'lacking', 'trouble', 'waste', 'debt', 'worst', 'isolated', 'difficulty', 'difficulties', 'lying', 'collapse', 'radical', 'disaster', 'outbreak', 'dies', 'noise', 'protests', 'breaks', 'disputed', 'conflicts', 'lie', 'resignation', 'exile', 'surrender', 'retreat', 'cave', 'unclear', 'prisoner', 'burning', 'disorder', 'allegations', 'kills', 'badly', 'strict', 'odd', 'dying', 'revenge', 'delay', 'upset', 'shock', 'mistake', 'scandal', 'complicated', 'complaints', 'infection', 'rivalry', 'fraud', 'propaganda', 'angry', 'toll', 'bore', 'bias', 'killer', 'hostile', 'massacre', 'disabled', 'trick', 'loose', 'blow', 'dense', 'smoke', 'crashed', 'terrorism', 'trapped', 'suffer', 'destroyer', 'elimination', 'vulnerable', 'lengthy', 'unsuccessfully', 'pale', 'flee', 'monster', 'cloud', 'fault', 'sunk', 'hurt', 'lacks', 'dust', 'myth', 'fake', 'fatal', 'limitations', 'obscure', 'primitive', 'trap', 'insufficient', 'rocky', 'notorious', 'drag', 'trivial', 'expired', 'static', 'bitter', 'strain', 'hate', 'damages', 'toxic', 'disruption', 'dissolution', 'puppet', 'demise', 'shocked', 'mistakes', 'nonsense', 'unexpected', 'funny', 'subjected', 'decay', 'restriction', 'isolation', 'cheap', 'sin', 'fears', 'irregular', 'objections', 'refusing', 'suspicious', 'refusal', 'persecution', 'declining', 'reluctant', 'obsolete', 'redundant', 'racism', 'breakdown', 'passive', 'erosion', 'darker', 'racist', 'damaging', 'deny', 'unusually', 'partisan', 'suspicion', 'loud', 'chaos', 'deadly', 'rumors', 'desperate', 'exploitation', 'disagreement', 'tired', 'questionable', 'debts', 'proprietary', 'incorrectly', 'hostage', 'splitting', 'rejection', 'misleading', 'adverse', 'failures', 'violate', 'irrelevant', 'pan', 'rigid', 'offence', 'disappointing', 'hang', 'guilt', 'crude', 'weakness', 'anxiety', 'accusing', 'tragic', 'unfortunately', 'overthrow', 'treason', 'knock', 'brutal', 'choke', 'suffers', 'stole', 'harmful', 'hatred', 'disastrous', 'trauma', 'unreliable', 'fleeing', 'sharply', 'genocide', 'pig', 'abusive', 'drain', 'vague', 'infringement', 'villains', 'mistress', 'confront', 'bankrupt', 'clash', 'drained', 'tortured', 'exhausted', 'bizarre', 'illegitimate', 'crack', 'lone', 'unacceptable', 'unfamiliar', 'contention', 'unfinished', 'epidemic', 'inequality', 'punch', 'inevitable', 'antagonist', 'unexpectedly', 'curse', 'accusation', 'abused', 'contentious', 'degradation', 'inaccurate', 'dubious', 'exploit', 'accidental', 'dirty', 'murderer', 'mistakenly', 'panic', 'stunt', 'denial', 'pigs', 'rejects', 'stern', 'invasive', 'mock', 'cry', 'recession', 'deaf', 'slowed', 'frustration', 'depressed', 'defects', 'unavailable', 'deprived', 'excuse', 'furious', 'ambush', 'rhetoric', 'confession', 'unfortunate', 'instability', 'objection', 'devil', 'congestion', 'restrict', 'crashes', 'jam', 'contamination', 'abuses', 'abruptly', 'ineffective', 'grief', 'hazardous', 'dragged', 'severity', 'fried', 'drastically', 'breakup', 'conspicuous', 'rumours', 'stricken', 'manipulate', 'impaired', 'regret', 'complaining', 'denying', 'concessions', 'liable', 'dislike', 'unemployed', 'unsure', 'neglect', 'leak', 'orphan', 'dull', 'stiff', 'ignorance', 'hazard', 'boiling', 'insult', 'fictitious', 'criticizing', 'ugly', 'defect', 'dictator', 'contempt', 'incivility', 'limitation', 'twisted', 'fatigue', 'intermittent', 'str ...

# %%
# Create list of words w/ sentiment from bigrams
words_sentiment = []
word_check = []
for bigram in filtered_headlines:
    word_dict = {}
    sentiment = 'not labelled'
    first_word = bigram[0][0]
    second_word = bigram[0][1]

    if first_word not in word_check:
        word_check.append(first_word)
        if first_word in pos_words:
            sentiment = 1
        if first_word in neg_words:
            sentiment = -1
        word_dict = {'id': first_word, 'group': sentiment}
        words_sentiment.append(word_dict)
        
        
    if second_word not in word_check:
        word_check.append(second_word)
        if second_word in pos_words:
            sentiment = 1
        if second_word in neg_words:
            sentiment = -1
        word_dict = {'id': second_word, 'group': sentiment}
        words_sentiment.append(word_dict)

# %%
# Check sentiment labels for accuracy
for word in words_sentiment:
    print(word)

# %%
# Revise sentiment labels
for word in words_sentiment:
    if word['group'] == 'not labelled':
        if word['id'] in ['terror', 'attack', 'battleground', 'illegal']:
            word['group'] = -1
        else:
            word['group'] = 0

# %%
# Check sentiment labels after editing
for word in words_sentiment:
    print(word)
# Out:
# {'id': 'ilhan', 'group': 0}
# {'id': 'omar', 'group': 0}
# {'id': 'hong', 'group': 0}
# {'id': 'kong', 'group': 0}
# {'id': 'ruth', 'group': 0}
# {'id': 'bader', 'group': 0}
# {'id': 'north', 'group': 0}
# {'id': 'carolina', 'group': 0}
# {'id': 'town', 'group': 0}
# {'id': 'hall', 'group': 0}
# {'id': 'pope', 'group': 0}
# {'id': 'francis', 'group': 0}
# {'id': 'ginsburg', 'group': 0}
# {'id': 'fox', 'group': 0}
# {'id': 'news', 'group': 0}
# {'id': 'amy', 'group': 0}
# {'id': 'coney', 'group': 0}
# {'id': 'barrett', 'group': 0}
# {'id': 'washington', 'group': 0}
# {'id': 'post', 'group': 0}
# {'id': 'wall', 'group': 0}
# {'id': 'street', 'group': 0}
# {'id': 'terror', 'group': -1}
# {'id': 'attack', 'group': -1}
# {'id': 'health', 'group': 0}
# {'id': 'care', 'group': 0}
# {'id': 'undocumented', 'group': -1}
# {'id': 'immigrant', 'group': -1}
# {'id': 'illegal', 'group': -1}
# {'id': 'alien', 'group': 0}
# {'id': 'supreme', 'group': 0}
# {'id': 'court', 'group': 0}
# {'id': 'new', 'group': 0}
# {'id': 'york', 'group': 0}
# {'id': 'vp', 'group': 0}
# {'id': 'debate', 'group': 0}
# {'id': 'border', 'group': 0}
# {'id': 'patrol', 'group': 0}
# {'id': 'white', 'group': 0}
# {'id': 'house', 'group': 0}
# {'id': 'presidential', 'group': 0}
# {'id': 'battleground', 'group': -1}
# {'id': 'state', 'group': 0}
# {'id': 'asian', 'group': 0}
# {'id': 'americans', 'group': 0}
# {'id': 'refugee', 'group': 0}
# {'id': 'camp', 'group': 0}
# {'id': 'migrant', 'group': 0}
# {'id': 'caravan', 'group': 0}
# {'id': 'latino', 'group': 0}
# {'id': 'voter', 'group': 0}
# {'id': 'immigration', 'group': 0}
# {'id': 'policy', 'group': 0}
# {'id': 'joe', 'group': 0}
# {'id': 'biden', 'group': 0}
# {'id': 'american', 'group': 0}
# {'id': 'election', 'group': 0}
# {'id': 'donald', 'group': 0}
# {'id': 'trump', 'group': 0}
# {'id': 'melania', 'group': 0}
# {'id': 'administration', 'group': 0}
# {'id': 'texas', 'group': 0}
# {'id': 'child', 'group': 0}
# {'id': 'win', 'group': 1}
# {'id': 'president', 'group': 0}
# {'id': '’s', 'group': 0}

# %%
# Format bigrams
links = []
for bigram in filtered_headlines:
    word_dict = {
        'source': bigram[0][0],
        'target': bigram[0][1],
        'value': round(bigram[1])
    }
    links.append(word_dict)
# Out:
# [{'source': 'ilhan', 'target': 'omar', 'value': 11}, {'source': 'hong', 'target': 'kong', 'value': 11}, {'source': 'ruth', 'target': 'bader', 'value': 11}, {'source': 'north', 'target': 'carolina', 'value': 11}, {'source': 'town', 'target': 'hall', 'value': 10}, {'source': 'pope', 'target': 'francis', 'value': 10}, {'source': 'bader', 'target': 'ginsburg', 'value': 10}, {'source': 'fox', 'target': 'news', 'value': 10}, {'source': 'amy', 'target': 'coney', 'value': 10}, {'source': 'coney', 'target': 'barrett', 'value': 10}, {'source': 'washington', 'target': 'post', 'value': 10}, {'source': 'wall', 'target': 'street', 'value': 10}, {'source': 'terror', 'target': 'attack', 'value': 9}, {'source': 'health', 'target': 'care', 'value': 9}, {'source': 'undocumented', 'target': 'immigrant', 'value': 9}, {'source': 'illegal', 'target': 'alien', 'value': 8}, {'source': 'supreme', 'target': 'court', 'value': 8}, {'source': 'new', 'target': 'york', 'value': 8}, {'source': 'vp', 'target': 'debate', 'value': 8}, {'source': 'border', 'target': 'patrol', 'value': 8}, {'source': 'white', 'target': 'house', 'value': 8}, {'source': 'presidential', 'target': 'debate', 'value': 8}, {'source': 'battleground', 'target': 'state', 'value': 8}, {'source': 'asian', 'target': 'americans', 'value': 7}, {'source': 'refugee', 'target': 'camp', 'value': 7}, {'source': 'migrant', 'target': 'caravan', 'value': 7}, {'source': 'border', 'target': 'wall', 'value': 7}, {'source': 'latino', 'target': 'voter', 'value': 7}, {'source': 'immigration', 'target': 'policy', 'value': 7}, {'source': 'joe', 'target': 'biden', 'value': 6}, {'source': 'american', 'target': 'voter', 'value': 6}, {'source': 'migrant', 'target': 'camp', 'value': 6}, {'source': 'illegal', 'target': 'immigrant', 'value': 6}, {'source': 'presidential', 'target': 'election', 'value': 6}, {'source': 'donald', 'target': 'trump', 'value': 6}, {'source': 'melania', 'target': 'trump', 'value': 6}, {'source': 'trump', 'target': 'administration', 'value': 6}, {'source': 'texas', 'target': 'border', 'value': 5}, {'source': 'migrant', 'target': 'child', 'value': 5}, {'source': 'illegal', 'target': 'immigration', 'value': 5}, {'source': 'illegal', 'target': 'migrant', 'value': 5}, {'source': 'biden', 'target': 'win', 'value': 4}, {'source': 'president', 'target': 'trump', 'value': 4}, {'source': 'trump', 'target': '’s', 'value': 4}, {'source': 'biden', 'target': '’s', 'value': 4}, {'source': 'trump', 'target': 'biden', 'value': 1}]

# %%
# Format data for arc diagram

headline_bigrams_formatted = {'nodes': words_sentiment, 'links': links}
# Out:
# {'nodes': [{'id': 'ilhan', 'group': 0}, {'id': 'omar', 'group': 0}, {'id': 'hong', 'group': 0}, {'id': 'kong', 'group': 0}, {'id': 'ruth', 'group': 0}, {'id': 'bader', 'group': 0}, {'id': 'north', 'group': 0}, {'id': 'carolina', 'group': 0}, {'id': 'town', 'group': 0}, {'id': 'hall', 'group': 0}, {'id': 'pope', 'group': 0}, {'id': 'francis', 'group': 0}, {'id': 'ginsburg', 'group': 0}, {'id': 'fox', 'group': 0}, {'id': 'news', 'group': 0}, {'id': 'amy', 'group': 0}, {'id': 'coney', 'group': 0}, {'id': 'barrett', 'group': 0}, {'id': 'washington', 'group': 0}, {'id': 'post', 'group': 0}, {'id': 'wall', 'group': 0}, {'id': 'street', 'group': 0}, {'id': 'terror', 'group': -1}, {'id': 'attack', 'group': -1}, {'id': 'health', 'group': 0}, {'id': 'care', 'group': 0}, {'id': 'undocumented', 'group': -1}, {'id': 'immigrant', 'group': -1}, {'id': 'illegal', 'group': -1}, {'id': 'alien', 'group': 0}, {'id': 'supreme', 'group': 0}, {'id': 'court', 'group': 0}, {'id': 'new', 'group': 0}, {'id': 'york', 'group': 0}, {'id': 'vp', 'group': 0}, {'id': 'debate', 'group': 0}, {'id': 'border', 'group': 0}, {'id': 'patrol', 'group': 0}, {'id': 'white', 'group': 0}, {'id': 'house', 'group': 0}, {'id': 'presidential', 'group': 0}, {'id': 'battleground', 'group': -1}, {'id': 'state', 'group': 0}, {'id': 'asian', 'group': 0}, {'id': 'americans', 'group': 0}, {'id': 'refugee', 'group': 0}, {'id': 'camp', 'group': 0}, {'id': 'migrant', 'group': 0}, {'id': 'caravan', 'group': 0}, {'id': 'latino', 'group': 0}, {'id': 'voter', 'group': 0}, {'id': 'immigration', 'group': 0}, {'id': 'policy', 'group': 0}, {'id': 'joe', 'group': 0}, {'id': 'biden', 'group': 0}, {'id': 'american', 'group': 0}, {'id': 'election', 'group': 0}, {'id': 'donald', 'group': 0}, {'id': 'trump', 'group': 0}, {'id': 'melania', 'group': 0}, {'id': 'administration', 'group': 0}, {'id': 'texas', 'group': 0}, {'id': 'child', 'group': 0}, {'id': 'win', 'group': 1}, {'id': 'president', 'group': 0}, {'id': '’s', 'group': 0}], 'links': [{'source': 'ilhan', 'target': 'omar', 'value': 11}, {'source': 'hong', 'target': 'kong', 'value': 11}, {'source': 'ruth', 'target': 'bader', 'value': 11}, {'source': 'north', 'target': 'carolina', 'value': 11}, {'source': 'town', 'target': 'hall', 'value': 10}, {'source': 'pope', 'target': 'francis', 'value': 10}, {'source': 'bader', 'target': 'ginsburg', 'value': 10}, {'source': 'fox', 'target': 'news', 'value': 10}, {'source': 'amy', 'target': 'coney', 'value': 10}, {'source': 'coney', 'target': 'barrett', 'value': 10}, {'source': 'washington', 'target': 'post', 'value': 10}, {'source': 'wall', 'target': 'street', 'value': 10}, {'source': 'terror', 'target': 'attack', 'value': 9}, {'source': 'health', 'target': 'care', 'value': 9}, {'source': 'undocumented', 'target': 'immigrant', 'value': 9}, {'source': 'illegal', 'target': 'alien', 'value': 8}, {'source': 'supreme', 'target': 'court', 'value': 8}, {'source': 'new', 'target': 'york', 'value': 8}, {'source': 'vp', 'target': 'debate', 'value': 8}, {'source': 'border', 'target': 'patrol', 'value': 8}, {'source': 'white', 'target': 'house', 'value': 8}, {'source': 'presidential', 'target': 'debate', 'value': 8}, {'source': 'battleground', 'target': 'state', 'value': 8}, {'source': 'asian', 'target': 'americans', 'value': 7}, {'source': 'refugee', 'target': 'camp', 'value': 7}, {'source': 'migrant', 'target': 'caravan', 'value': 7}, {'source': 'border', 'target': 'wall', 'value': 7}, {'source': 'latino', 'target': 'voter', 'value': 7}, {'source': 'immigration', 'target': 'policy', 'value': 7}, {'source': 'joe', 'target': 'biden', 'value': 6}, {'source': 'american', 'target': 'voter', 'value': 6}, {'source': 'migrant', 'target': 'camp', 'value': 6}, {'source': 'illegal', 'target': 'immigrant', 'value': 6}, {'source': 'presidential', 'target': 'election', 'value': 6}, {'source': 'donald', 'target': 'trump', 'value': 6}, {'source': 'melania', 'target': 'trump', 'value': 6}, {'source': 'trump', 'target': 'administrati ...

# %%
# TODO: Upload to MongoDB

# %%
# TODO: Repeat this process for full text of articles
